# %% [markdown]
# # Tratamiento de datos masivos
#
# ## Práctica 2
# ## Tratamiento de datos masivos - Facultad de Informática - Pablo C. Cañizares
#
# - Se valorará la claridad del código y evitar redundancias o código poco eficiente; en particular se valorará lograr el resultado de las consultas mediante MongoDB minimizando el uso de Python. En particular en el caso de usar `find` se valorará que se pidan justo los documentos que se necesitan (primer argumento) y justo de ellos la información que se requiere (segundo argumento)
# - Además de las funciones que se piden se pueden añadir otras auxiliares si se necesitan, y también otros imports
# - El código debe funcionar correctamente no solo con las pruebas que vienen de ejemplo sino con cualquier otra prueba
#
# Se requiere tener acceso a un servidor, ya sea arrancado en local o en la nube. Comprobar con el siguiento código si se puede acceder a él:

# %%
# cambiar si hace falta, ahora está para servidor local
url_servidor = "mongodb://127.0.0.1:27017/"

import sys

# comprobar si pymongo está instalado, y hacerlo en otro caso
try:
    import pymongo

    print("pymongo está en el sistema!")
except ImportError as e:
    # !{sys.executable} -m pip install --upgrade --user pymongo
    import pymongo

try:
    import pprint

    print("pprint está en el sistema!")
except ImportError as e:
    # !{sys.executable} -m pip install --upgrade --user pprint
    import pprint

try:
    import urllib

    print("urllib está en el sistema!")
except ImportError as e:
    # !{sys.executable} -m pip install --upgrade --user urllib
    import urllib

from pprint import pprint  # para mostrar los json bonitos
from pymongo import MongoClient

# Atlas:
# client = MongoClient("mongodb+srv://aniceto:castañas@cluster0.nubot.mongodb.net/test?retryWrites=true&w=majority")
client = MongoClient(url_servidor)

# código para ver si se ha conectado bien
try:
    s = client.server_info()  # si hay error tendremos una excepción
    print("Conectado a MongoDB, versión", s["version"])
except:
    print("Error de conexión ¿está arrancado el servidor?")
# Out:
# pymongo está en el sistema!
# pprint está en el sistema!
# urllib está en el sistema!
# Conectado a MongoDB, versión 7.0.14

# %% [markdown]
# Ahora cargamos datos al servidor desde la red

# %%
import json  # para transformar la línea leida (string) a json
import urllib.request  # para leer de la URL línea a línea


def carga_desde_fichero(db, fichero, coleccion):
    db[coleccion].drop()  # la borramos
    exito, error = 0, 0
    # cargamos los datos desde el fichero
    try:
        with urllib.request.urlopen(fichero) as f:
            for line in f:
                line2 = line.decode("UTF-8").replace("$", "")
                res = db[coleccion].insert_one(json.loads(line2))
                if res.acknowledged:
                    exito += 1
                else:
                    error += 1
        print(
            f"Colección {coleccion}: {exito} documentos cargados con éxito y {error} errores"
        )
    except urllib.error.URLError as e:
        print(e.reason)


db = client.practica2
fichero_tweets = (
    "https://raw.githubusercontent.com/RafaelCaballero/tdm/master/datos/ctweet.json"
)
carga_desde_fichero(db, fichero_tweets, "tweet")
# Out:
# Colección tweet: 3022 documentos cargados con éxito y 0 errores

# %% [markdown]
# Veamos qué aspecto tienen los ducumentos que hemos cargado

# %%
for doc in list(db.tweet.find().limit(100)):
    pprint(doc)
    print("*" * 80)
# Out:
# {'RT': False,
#  '_id': '1188094205299703809',
#  'created_at': {'date': '2019-10-26T14:05:06Z'},
#  'hashtags': [],
#  'lang': 'und',
#  'nRTin': 0,
#  'nquotein': 35,
#  'nreplyin': 0,
#  'reply': False,
#  'screen_name': 'DanScavino',
#  'symbols': [],
#  'text': 'https://t.co/iAbQ5Ip3bW https://t.co/GHMeQQqw1x',
#  'user_mentions': [],
#  'userid': '620571475'}
# ********************************************************************************
# {'RT': False,
#  '_id': '1188453559391666178',
#  'coordinates': {'coordinates': [-75.04539574, 40.16216216], 'type': 'Point'},
#  'created_at': {'date': '2019-10-27T13:53:03Z'},
#  'hashtags': [{'indices': [45, 52], 'text': 'judges'},
#               {'indices': [91, 97], 'text': 'Trump'},
#               {'indices': [102, 114], 'text': 'evangelical'}],
#  'lang': 'en',
#  'nRTin': 0,
#  'nquotein': 1,
#  'nreplyin': 0,
#  'reply': False,
#  'screen_name': 'PhillyPartTwo',
#  'symbols': [],
#  'text': 'Unqualified ultra-conservative young federal #judges that serve no '
#          'purpose but to push the #Trump and #evangelical agenda who will '
#          "preside for forty years will be Trump's lasting legacy over anything "
#          'else. His bigotry and misogyny will be the rule of law for '
#          'generations. https://t.co/LzNNJKNaiK',
#  'user_mentions': [],
#  'userid': '108416118'}
# ********************************************************************************
# {'RT': False,
#  '_id': '1190057966520668162',
#  'created_at': {'date': '2019-11-01T00:08:24Z'},
#  'hashtags': [],
#  'lang': 'en',
#  'nRTin': 1373,
#  'nquotein': 73,
#  'nreplyin': 49,
#  'quote': False,
#  'reply': False,
#  'screen_name': 'LionelMedia',
#  'symbols': [],
#  'text': 'Retweet if you stand with \u2066@realDonaldTrump\u2069! '
#          'https://t.co/3ju6dzvO2S',
#  'user_mentions': [{'id': 25073877,
#                     'id_str': '25073877',
#                     'indices': [27, 43],
#                     'name': 'Donald J. Trump',
#                     'screen_name': 'realDonaldTrump'}],
#  'userid': '24787367'}
# ********************************************************************************
# {'RT': False,
#  '_id': '1190444836505182208',
#  'created_at': {'date': '2019-11-02T01:45:41Z'},
#  'hashtags': [{'indices': [87, 104], 'text': 'BeatHimLikeADrum'}],
#  'lang': 'en',
#  'nRTin': 1,
#  'nquotein': 0,
#  'nreplyin': 0,
#  'quote': False,
#  'reply': False,
#  'screen_name': 'rdjkazmi',
#  'symbols': [],
#  'text': 'A divided house but still @TheDemocrats. That said, I’m “Ridin’ with '
#          'Biden”! @JoeBiden #BeatHimLikeADrum #IowaForBiden #Dems2020 '
#          '@schultzohio @ClaudieEsmee https://t.co/RuEpFcy064',
#  'user_mentions': [{'id': 14377605,
#                     'id_str': '14377605',
#                     'indices': [26, 39],
#                     'name': 'The Democrats',
#                     'screen_name': 'TheDemocrats'},
#                    {'id': 939091,
#                     'id_str': '939091',
#                     'indices': [77, 86],
#                     'name': 'Joe Biden',
#                     'screen_name': 'JoeBiden'}],
#  'userid': '2954922809'}
# ********************************************************************************
# {'RT': False,
#  '_id': '1196575471258996741',
#  'coordinates': {'coordinates': [28.7645423, 41.0550449], 'type': 'Point'},
#  'created_at': {'date': '2019-11-18T23:46:38Z'},
#  'hashtags': [{'indices': [60, 66], 'text': 'Trump'},
#               {'indices': [67, 83], 'text': 'thesingingtrump'},
#               {'indices': [84, 96], 'text': 'NewYorkCity'},
#               {'indices': [97, 110], 'text': 'WashingtonDC'}],
#  'lang': 'en',
#  'nRTin': 1,
#  'nquotein': 0,
#  'nreplyin': 0,
#  'quote': False,
#  'reply': False,
#  'screen_name': 'Cabdull13822073',
#  'symbols': [],
#  'text': "I'm Late but, he is the lost twin of the Halloween costume. #Trump "
#          '#thesingingtrump #NewYorkCity #WashingtonDC #WhiteHouse #politics '
#          '#LateLateShow #EllenDeGeneres #BBCWorkLife #trtworld #HongKong '
#          '#America #NEW #Headline #funny #Trump2020  #imamoğlu '
#          '#TrendingInChina #TrendingNow https://t.co/UE5fgtVtse',
#  'user_mentions': [],
#  'userid': '1088729740930936832'}
# ********************************************************************************
# {'RT': False,
#  '_id': '1224955461310599168',
#  'coordinates': {'coordinates': [-84.4125, 33.5726], 'type': 'Point'},
#  'created_at': {'date': '2020-02-05T07:18:35Z'},
#  'hashtags': [{'indices': [28, 36], 'text': 'ATLANTA'},
#               {'indices': [37, 46], 'text': 'weedporn'},
#               {'indices': [47, 52], 'text': 'weed'},
#               {'indices': [53, 62], 'text': 'weedclan'},
#               {'indices': [64, 75], 'text': 'rawlife247'},
#               {'indices': [76, 84], 'text': 'rawlife'},
#               {'indices': [85, 91], 'text': 'ganja'},
#               {'indices': [93, 106], 'text': 'BHOssBytcheZ'}],
#  'lang': 'en',
#  'nRTin': 1,
#  'nquotein': 0,
#  'nreplyin': 0,
#  'quote': False,
#  'reply': False,
#  'screen_name': 'BLITZTHEENT',
#  'symbols': [],
#  'text': 'clockwiserami\n'
#          'FridayHighDay #ATLANTA\n'
#          '#weedporn #weed #weedclan \n'
#          '#rawlife247 #rawlife #ganja \n'
#          '#BHOssBytcheZ #february\n'
#          '#trump #highsociety #hightimes \n'
#          '#potheadsociety #pothead #brooklyn\n'
#          '#stonernation #stoned… https://t.co/XmrkfIG2WK',
#  'user_mentions': [],
#  'userid': '39562650'}
# ********************************************************************************
# {'RT': False,
#  '_id': '1229634552022421504',
#  'created_at': {'date': '2020-02-18T05:11:37Z'},
#  'hashtags': [],
#  'lang': 'en',
#  'nRTin': 2,
#  'nquotein': 0,
#  'nreplyin': 0,
#  'quote': False,
#  'reply': False,
#  'screen_name': 'TiffanyATrump',
#  'symbols': [],
#  'text': 'Happy Presidents’ Day to my incredible father @realDonaldTrump and '
#          'our country’s great leaders of the past and present ❤️🤍💙 '
#          '#PresidentsDay https://t.co/4kmc7pbqWd',
#  'user_mentions': [{'id': 25073877,
#                     'id_str': '25073877',
#                     'indices': [46, 62],
#                     'name': 'Donald J. Trump',
#                     'screen_name': 'realDonaldTrump'}],
#  'userid': '245963716'}
# ********************************************************************************
# {'RT': False,
#  '_id': '1271684260387270656',
#  'created_at': {'date': '2020-06-13T06:02:09Z'},
#  'hashtags': [],
#  'lang': 'en',
#  'nRTin': 1,
#  'nquotein': 0,
#  'nreplyin': 0,
#  'quote': False,
#  'reply': False,
#  'screen_name': 'dannyhellman',
#  'symbols': [],
#  'text': "Hadn't seen this one before. Here's @JoeBiden defending his crime "
#          'bill by suggesting that crack users deserved harsher sentencing than '
#          '"someone in a beautiful neighborhood like this sniffing a line of '
#          'cocaine." #NeverBiden #DemExit2020 https://t.co/umjoQp5zZ6',
#  'user_mentions': [{'id': 939091,
#                     'id_str': '939091',
#                     'indices': [36, 45],
#                     'name': 'Joe Biden',
#                     'screen_name': 'JoeBiden'}],
#  'userid': '32532994'}
# ********************************************************************************
# {'RT': False,
#  '_id': '1272350470644871169',
#  'created_at': {'date': '2020-06-15T02:09:25Z'},
#  'hashtags': [],
#  'lang': 'en',
#  'nRTin': 2,
#  'nquotein': 1,
#  'nreplyin': 1,
#  'quote': False,
#  'reply': False,
#  'screen_name': 'TiffanyATrump',
#  'symbols': [],
#  'text': 'Happy Birthday Dad! @realdonaldtrump I’m so grateful for your love '
#          'and guidance. I love you! https://t.co/QMl6KZiMEf',
#  'user_mentions': [{'id': 25073877,
#                     'id_str': '25073877',
#                     'indices': [20, 36],
#                     'name': 'Donald J. Trump',
#                     'screen_name': 'realDonaldTrump'}],
#  'userid': '245963716'}
# ********************************************************************************
# {'RT': False,
#  '_id': '1272352441422536705',
#  'created_at': {'date': '2020-06-15T02:17:15Z'},
#  'hashtags': [],
#  'lang': 'en',
#  'nRTin': 7,
#  'nquotein': 0,
#  'nreplyin': 1,
#  'quote': False,
#  'reply': False,
#  'screen_name': 'TiffanyATrump',
#  'symbols': [],
#  'text': 'Happy Birthday Dad! @realDonaldTrump I’m so grateful for your love '
#          'and guidance. I love you! https://t.co/la0yz2mkDK',
#  'user_mentions': [{'id': 25073877,
#                     'id_str': '25073877',
#                     'indices': [20, 36],
#                     'name': 'Donald J. Trump',
#                     'screen_name': 'realDonaldTrump'}],
#  'userid': '245963716'}
# ********************************************************************************
# {'RT': False,
#  '_id': '1274823395528650752',
#  'coordinates': {'coordinates': [-77.03649486, 38.89769958], 'type': 'Point'},
#  'created_at': {'date': '2020-06-21T21:55:57Z'},
#  'hashtags': [],
#  'lang': 'en',
#  'nRTin': 2,
#  'nquotein': 0,
#  'nreplyin': 2,
#  'quote': False,
#  'reply': False,
#  'screen_name': 'TiffanyATrump',
#  'symbols': [],
#  'text': 'Happy Father’s Day Dad! @realdonaldtrump I love you and I’m so '
#          'grateful for you! Thank you for your constant love, guidance and for '
#          'always believing in me! @ The White House https://t.co/Q94DbCobkG',
#  'user_mentions': [{'id': 25073877,
#                     'id_str': '25073877',
#                     'indices': [24, 40],
#                     'name': 'Donald J. Trump',
#                     'screen_name': 'realDonaldTrump'}],
#  'userid': '245963716'}
# ********************************************************************************
# {'RT': False,
#  '_id': '1274823885607833600',
#  'created_at': {'date': '2020-06-21T21:57:54Z'},
#  'hashtags': [],
#  'lang': 'en',
#  'nRTin': 9,
#  'nquotein': 0,
#  'nreplyin': 6,
#  'quote': False,
#  'reply': False,
#  'screen_name': 'TiffanyATrump',
#  'symbols': [],
#  'text': 'Happy Father’s Day Dad! @realdonaldtrump I love you and I’m so '
#          'grateful for you! Thank you for your constant love, guidance and for '
#          'always believing in me! https://t.co/5cmIbXFvEN',
#  'user_mentions': [{'id': 25073877,
#                     'id_str': '25073877',
#                     'indices': [24, 40],
#                     'name': 'Donald J. Trump',
#                     'screen_name': 'realDonaldTrump'}],
#  'userid': '245963716'}
# ********************************************************************************
# {'RT': False,
#  '_id': '1289647652804554752',
#  'coordinates': {'coordinates': [-80.93224582, 35.2972973], 'type': 'Point'},
#  'created_at': {'date': '2020-08-01T19:42:15Z'},
#  'hashtags': [{'indices': [81, 91], 'text': 'tiktokban'},
#               {'indices': [92, 98], 'text': 'trump'},
#               {'indices': [99, 105], 'text': 'karen'},
#               {'indices': [106, 112], 'text': 'covid'}],
#  'lang': 'en',
#  'nRTin': 1,
#  'nquotein': 0,
#  'nreplyin': 0,
#  'quote': False,
#  'reply': False,
#  'screen_name': '1_Tru_G',
#  'symbols': [],
#  'text': 'LMFAAAAOOOO..THIS IS FUNNY!!!!🤣🤣** RT @BlakePavey: GLOBAL UPDATE: '
#          'USA TIKTOK BAN #tiktokban #trump #karen #covid (Insta/YouTube - '
#          '@blakepavey) https://t.co/2sDynVaHVZ',
#  'user_mentions': [{'id': 918218955914801152,
#                     'id_str': '918218955914801152',
#                     'indices': [38, 49],
#                     'name': 'Blake Pavey',
#                     'screen_name': 'BlakePavey'}],
#  'userid': '140623364'}
# ********************************************************************************
# {'RT': False,
#  '_id': '1299881504835801088',
#  'created_at': {'date': '2020-08-30T01:27:56Z'},
#  'hashtags': [{'indices': [56, 80], 'text': 'childtraffickingexposed'}],
#  'lang': 'en',
#  'nRTin': 1,
#  'nquotein': 0,
#  'nreplyin': 0,
#  'quote': False,
#  'reply': False,
#  'screen_name': 'ComedianKD',
#  'symbols': [],
#  'text': 'So please share... if you type BAGETS on @facebook alot '
#          '#childtraffickingexposed sites pop up! @MarkZuckerbeg where are you '
#          'on this?! @POTUS @IvankaTrump @RealEricTeump we need this stopped!! '
#          '#parenting #kids you too @JoeBiden wtf https://t.co/KMRLFR7wbM',
#  'user_mentions': [{'id': 2425151,
#                     'id_str': '2425151',
#                     'indices': [41, 50],
#                     'name': 'Facebook',
#                     'screen_name': 'Facebook'},
#                    {'id': 375900204,
#                     'id_str': '375900204',
#                     'indices': [95, 109],
#                     'name': 'Mark Zuckerbeg',
#                     'screen_name': 'MarkZuckerbeg'}],
#  'userid': '25125132'}
# ********************************************************************************
# {'RT': False,
#  '_id': '1302216521268236289',
#  'created_at': {'date': '2020-09-05T12:06:27Z'},
#  'hashtags': [],
#  'lang': 'en',
#  'nRTin': 1,
#  'nquotein': 0,
#  'nreplyin': 0,
#  'quote': False,
#  'reply': False,
#  'screen_name': 'FrStephenImb',
#  'symbols': [],
#  'text': '... the greatest destroyer of peace today is abortion, because it is '
#          'a war against the child, a direct killing of the innocent child, '
#          'murder by the mother herself.” @JoeBiden #scandal @realDonaldTrump '
#          '#newlincoln #abortionismurder #catholic https://t.co/b6E79fQxiJ',
#  'user_mentions': [],
#  'userid': '108193922'}
# ********************************************************************************
# {'RT': False,
#  '_id': '1303418241730183168',
#  'created_at': {'date': '2020-09-08T19:41:39Z'},
#  'hashtags': [],
#  'lang': 'en',
#  'nRTin': 0,
#  'nquotein': 4,
#  'nreplyin': 639,
#  'quote': False,
#  'reply': False,
#  'screen_name': 'TiffanyATrump',
#  'symbols': [],
#  'text': '“This election, I urge you to transcend political boundaries — to '
#          'make your judgment based on results and not rhetoric. This is a '
#          'fight for freedom versus oppression, for opportunity versus '
#          'stagnation, a fight to keep America true to America.” - TT '
#          'https://t.co/Z2dsfvFCiJ',
#  'user_mentions': [],
#  'userid': '245963716'}
# ********************************************************************************
# {'RT': False,
#  '_id': '1305934530902138886',
#  'created_at': {'date': '2020-09-15T18:20:29Z'},
#  'hashtags': [],
#  'lang': 'en',
#  'nRTin': 2,
#  'nquotein': 0,
#  'nreplyin': 1,
#  'quote': True,
#  'reply': False,
#  'screen_name': 'JackBrewerBSI',
#  'symbols': [],
#  'text': 'Such an honor to be guest of the @WhiteHouse and the amazing @FLOTUS '
#          '- My family and I will continue to support @realDonaldTrump tireless '
#          'efforts to bring resources and solutions to issues effecting '
#          'underserved African Americans across our nation. #GloryToGod',
#  'user_mentions': [{'id': 822215673812119553,
#                     'id_str': '822215673812119553',
#                     'indices': [33, 44],
#                     'name': 'The White House',
#                     'screen_name': 'WhiteHouse'},
#                    {'id': 818876014390603776,
#                     'id_str': '818876014390603776',
#                     'indices': [61, 68],
#                     'name': 'Melania Trump',
#                     'screen_name': 'FLOTUS'}],
#  'userid': '78685709'}
# ********************************************************************************
# {'RT': False,
#  '_id': '1307559456604065793',
#  'created_at': {'date': '2020-09-20T05:57:22Z'},
#  'hashtags': [],
#  'lang': 'en',
#  'nRTin': 81,
#  'nquotein': 7,
#  'nreplyin': 20,
#  'quote': False,
#  'reply': False,
#  'screen_name': 'DanScavino',
#  'symbols': [],
#  'text': 'Congratulations @ColbyCovMMA! Great moment tonight when POTUS '
#          '@realDonaldTrump calls him in the middle of a live interview, after '
#          'his BIG W — love it! #UFCVegas11 #MAGA🇺🇸🦅 https://t.co/x3AweYoeif',
#  'user_mentions': [{'id': 442456291,
#                     'id_str': '442456291',
#                     'indices': [16, 28],
#                     'name': 'Colby Covington',
#                     'screen_name': 'ColbyCovMMA'},
#                    {'id': 25073877,
#                     'id_str': '25073877',
#                     'indices': [62, 78],
#                     'name': 'Donald J. Trump',
#                     'screen_name': 'realDonaldTrump'}],
#  'userid': '620571475'}
# ********************************************************************************
# {'RT': False,
#  '_id': '1308745607344009216',
#  'created_at': {'date': '2020-09-23T12:30:42Z'},
#  'hashtags': [],
#  'lang': 'en',
#  'nRTin': 1,
#  'nquotein': 0,
#  'nreplyin': 0,
#  'quote': True,
#  'reply': False,
#  'screen_name': 'JackBrewerBSI',
#  'symbols': [],
#  'text': 'This is unbelievable.. https://t.co/aIy2P1nVjn',
#  'user_mentions': [],
#  'userid': '78685709'}
# ********************************************************************************
# {'RT': False,
#  '_id': '1309112603352985600',
#  'created_at': {'date': '2020-09-24T12:49:01Z'},
#  'hashtags': [],
#  'lang': 'en',
#  'nRTin': 1,
#  'nquotein': 0,
#  'nreplyin': 0,
#  'quote': True,
#  'reply': False,
#  'screen_name': 'JackBrewerBSI',
#  'symbols': [],
#  'text': 'Since 2016, the SEC/FBI has used 10 tax payer funded lawyers to '
#          'shake me down over a 35,000 civil trade dispute, all because I '
#          'support @realDonaldTrump. While ignoring @JoeBiden family schemes to '
#          'bring billions from China, UKR &amp; Russia. If I was a '
#          '@TheDemocrats I’d blame RACISM! https://t.co/5rwMrGihcl',
#  'user_mentions': [],
#  'userid': '78685709'}
# ********************************************************************************
# {'RT': False,
#  '_id': '1309555721965453312',
#  'created_at': {'date': '2020-09-25T18:09:49Z'},
#  'hashtags': [],
#  'lang': 'en',
#  'nRTin': 12,
#  'nquotein': 0,
#  'nreplyin': 0,
#  'quote': True,
#  'reply': False,
#  'screen_name': 'DanScavino',
#  'symbols': [],
#  'text': 'President Trump on pre-existing conditions, yesterday:\n'
#          '\n'
#          '“The historic action I took today includes the first-ever executive '
#          'order to affirm it is the official policy of the U.S. Government to '
#          'protect patients with pre-existing conditions.” @realDonaldTrump '
#          'https://t.co/g5mlZHoPTh https://t.co/NwzjcZ88oT',
#  'user_mentions': [],
#  'userid': '620571475'}
# ********************************************************************************
# {'RT': False,
#  '_id': '1309640769314213888',
#  'created_at': {'date': '2020-09-25T23:47:46Z'},
#  'hashtags': [],
#  'lang': 'en',
#  'nRTin': 24,
#  'nquotein': 7,
#  'nreplyin': 13,
#  'quote': False,
#  'reply': False,
#  'screen_name': 'DanScavino',
#  'symbols': [],
#  'text': 'Florida this morning, Georgia this afternoon, Washington, D.C. this '
#          'evening, and now — President @realDonaldTrump departing Washington, '
#          'D.C. for a MAGA Rally in Newport News, Virginia! Wheels up shortly! '
#          '#MAGA🇺🇸🦅 https://t.co/XxFKpnw4ms',
#  'user_mentions': [{'id': 25073877,
#                     'id_str': '25073877',
#                     'indices': [97, 113],
#                     'name': 'Donald J. Trump',
#                     'screen_name': 'realDonaldTrump'}],
#  'userid': '620571475'}
# ********************************************************************************
# {'RT': False,
#  '_id': '1310404142523973632',
#  'created_at': {'date': '2020-09-28T02:21:08Z'},
#  'hashtags': [{'indices': [81, 92], 'text': 'Louisville'},
#               {'indices': [93, 112], 'text': 'LouisvilleProtests'}],
#  'lang': 'en',
#  'nRTin': 0,
#  'nquotein': 1,
#  'nreplyin': 0,
#  'quote': False,
#  'reply': False,
#  'screen_name': 'BGOnTheScene',
#  'symbols': [],
#  'text': 'Black Lives Matter march making its way through downtown Louisville '
#          'this evening #Louisville #LouisvilleProtests #BlackLivesMatter '
#          'https://t.co/AGiD6RFDSC',
#  'user_mentions': [],
#  'userid': '23951440'}
# ********************************************************************************
# {'RT': False,
#  '_id': '1310671475091873792',
#  'coordinates': {'coordinates': [-77.0387238, 38.8976805], 'type': 'Point'},
#  'created_at': {'date': '2020-09-28T20:03:25Z'},
#  'hashtags': [],
#  'in_reply_to_screen_name': 'WhiteHouse',
#  'in_reply_to_status_id_str': '1310671338634444802',
#  'in_reply_to_user_id_str': '822215673812119553',
#  'lang': 'en',
#  'nRTin': 1,
#  'nquotein': 0,
#  'nreplyin': 0,
#  'quote': False,
#  'reply': True,
#  'screen_name': 'DaysLeft4Trump',
#  'symbols': [],
#  'text': '@WhiteHouse @realDonaldTrump 3 Months, 22 Days, 20 Hours, 57 '
#          'Minutes, and 1 Second',
#  'user_mentions': [{'id': 822215673812119553,
#                     'id_str': '822215673812119553',
#                     'indices': [0, 11],
#                     'name': 'The White House',
#                     'screen_name': 'WhiteHouse'},
#                    {'id': 25073877,
#                     'id_str': '25073877',
#                     'indices': [12, 28],
#                     'name': 'Donald J. Trump',
#                     'screen_name': 'realDonaldTrump'}],
#  'userid': '822491959805825027'}
# ********************************************************************************
# {'RT': False,
#  '_id': '1310791096138706945',
#  'created_at': {'date': '2020-09-29T03:58:45Z'},
#  'hashtags': [],
#  'lang': 'en',
#  'nRTin': 0,
#  'nquotein': 14,
#  'nreplyin': 840,
#  'quote': False,
#  'reply': False,
#  'screen_name': 'realDonaldTrump',
#  'symbols': [],
#  'text': 'Now Fake News @CNN is actually reporting that I wanted my daughter, '
#          'Ivanka, to run with me as my Vice President in 2016 Election. Wrong '
#          'and totally ridiculous. These people are sick!',
#  'user_mentions': [{'id': 759251,
#                     'id_str': '759251',
#                     'indices': [14, 18],
#                     'name': 'CNN',
#                     'screen_name': 'CNN'}],
#  'userid': '25073877'}
# ********************************************************************************
# {'RT': False,
#  '_id': '1310918927527149569',
#  'created_at': {'date': '2020-09-29T12:26:42Z'},
#  'hashtags': [],
#  'lang': 'und',
#  'nRTin': 0,
#  'nquotein': 4,
#  'nreplyin': 0,
#  'quote': False,
#  'reply': False,
#  'screen_name': 'DanScavino',
#  'symbols': [],
#  'text': 'https://t.co/yuN1BsBA5M',
#  'user_mentions': [],
#  'userid': '620571475'}
# ********************************************************************************
# {'RT': False,
#  '_id': '1310938491883327493',
#  'created_at': {'date': '2020-09-29T13:44:27Z'},
#  'hashtags': [],
#  'lang': 'en',
#  'nRTin': 1,
#  'nquotein': 0,
#  'nreplyin': 0,
#  'quote': False,
#  'reply': False,
#  'screen_name': 'Joy_Villa',
#  'symbols': [],
#  'text': 'President @realDonaldTrump has received THREE separate Nobel Peace '
#          'Prize nominations for his foreign policy! INCREDIBLE!',
#  'user_mentions': [{'id': 25073877,
#                     'id_str': '25073877',
#                     'indices': [10, 26],
#                     'name': 'Donald J. Trump',
#                     'screen_name': 'realDonaldTrump'}],
#  'userid': '63335631'}
# ********************************************************************************
# {'RT': False,
#  '_id': '1310970857930489859',
#  'created_at': {'date': '2020-09-29T15:53:03Z'},
#  'hashtags': [],
#  'lang': 'en',
#  'nRTin': 2272,
#  'nquotein': 7,
#  'nreplyin': 385,
#  'quote': True,
#  'reply': False,
#  'screen_name': 'realDonaldTrump',
#  'symbols': [],
#  'text': 'A GREAT HONOR, THANK YOU!!',
#  'user_mentions': [],
#  'userid': '25073877'}
# ********************************************************************************
# {'RT': False,
#  '_id': '1311032604351705092',
#  'created_at': {'date': '2020-09-29T19:58:25Z'},
#  'hashtags': [{'indices': [32, 44], 'text': 'Debates2020'},
#               {'indices': [45, 50], 'text': 'MAGA'}],
#  'lang': 'en',
#  'nRTin': 0,
#  'nquotein': 12,
#  'nreplyin': 3,
#  'quote': False,
#  'reply': False,
#  'screen_name': 'DanScavino',
#  'symbols': [],
#  'text': 'Wheels down in Cleveland, Ohio! #Debates2020 #MAGA🇺🇸🦅 '
#          'https://t.co/mA6lrrWSd5',
#  'user_mentions': [],
#  'userid': '620571475'}
# ********************************************************************************
# {'RT': False,
#  '_id': '1311051607442944007',
#  'created_at': {'date': '2020-09-29T21:13:56Z'},
#  'hashtags': [],
#  'lang': 'en',
#  'nRTin': 0,
#  'nquotein': 82,
#  'nreplyin': 4842,
#  'quote': False,
#  'reply': False,
#  'screen_name': 'realDonaldTrump',
#  'symbols': [],
#  'text': 'Just arrived in the Great State of Ohio. Real Polls have us leading '
#          'by even more than 2016. With Biden being against Fracking (Energy '
#          '&amp; Jobs) &amp; your Second Amendment, we should be in very good '
#          'shape!',
#  'user_mentions': [],
#  'userid': '25073877'}
# ********************************************************************************
# {'RT': False,
#  '_id': '1311051647687307264',
#  'created_at': {'date': '2020-09-29T21:14:05Z'},
#  'hashtags': [],
#  'lang': 'en',
#  'nRTin': 0,
#  'nquotein': 434,
#  'nreplyin': 6440,
#  'quote': False,
#  'reply': False,
#  'screen_name': 'realDonaldTrump',
#  'symbols': [],
#  'text': 'Wow. Won’t let Poll Watchers &amp; Security into Philadelphia Voting '
#          'Places. There is only one reason why. Corruption!!! Must have a fair '
#          'Election.',
#  'user_mentions': [],
#  'userid': '25073877'}
# ********************************************************************************
# {'RT': False,
#  '_id': '1311057015591104514',
#  'created_at': {'date': '2020-09-29T21:35:25Z'},
#  'hashtags': [],
#  'lang': 'en',
#  'nRTin': 0,
#  'nquotein': 0,
#  'nreplyin': 0,
#  'quote': False,
#  'reply': False,
#  'screen_name': 'lizamileshappy',
#  'symbols': [],
#  'text': "@JoeBiden say it isn't so!\nhttps://t.co/26aL1rjo0d",
#  'user_mentions': [{'id': 939091,
#                     'id_str': '939091',
#                     'indices': [0, 9],
#                     'name': 'Joe Biden',
#                     'screen_name': 'JoeBiden'}],
#  'userid': '131745292'}
# ********************************************************************************
# {'RT': True,
#  'RT_source': '1311055297763475456',
#  '_id': '1311057823317463040',
#  'checkRT': True,
#  'created_at': {'date': '2020-09-29T21:38:38Z'},
#  'lang': 'en',
#  'nRTin': 0,
#  'nquotein': 0,
#  'nreplyin': 0,
#  'quote': False,
#  'reply': False,
#  'screen_name': 'ceedub001',
#  'userid': '37513528'}
# ********************************************************************************
# {'RT': True,
#  'RT_source': '1311011462295425029',
#  '_id': '1311060044985675777',
#  'checkRT': True,
#  'created_at': {'date': '2020-09-29T21:47:27Z'},
#  'lang': 'en',
#  'nRTin': 0,
#  'nquotein': 0,
#  'nreplyin': 0,
#  'quote': False,
#  'reply': False,
#  'screen_name': 'ceedub001',
#  'userid': '37513528'}
# ********************************************************************************
# {'RT': False,
#  '_id': '1311061369219952641',
#  'created_at': {'date': '2020-09-29T21:52:43Z'},
#  'hashtags': [{'indices': [69, 81], 'text': 'Debates2020'},
#               {'indices': [82, 96], 'text': 'DebateTuesday'},
#               {'indices': [97, 107], 'text': 'Cleveland'}],
#  'lang': 'en',
#  'nRTin': 0,
#  'nquotein': 1,
#  'nreplyin': 1,
#  'quote': False,
#  'reply': False,
#  'screen_name': 'BGOnTheScene',
#  'symbols': [],
#  'text': 'Military Police out on the streets of Cleveland for tonight’s debate '
#          '#Debates2020 #DebateTuesday #Cleveland https://t.co/N8kvKEf3bs',
#  'user_mentions': [],
#  'userid': '23951440'}
# ********************************************************************************
# {'RT': False,
#  '_id': '1311066006945763330',
#  'coordinates': {'coordinates': [-86.3624, 43.4154], 'type': 'Point'},
#  'created_at': {'date': '2020-09-29T22:11:09Z'},
#  'hashtags': [],
#  'lang': 'en',
#  'nRTin': 0,
#  'nquotein': 0,
#  'nreplyin': 0,
#  'quote': False,
#  'reply': False,
#  'screen_name': 'H2O_MaggieO',
#  'symbols': [],
#  'text': 'Let’s try this again... although I’m sure the person who stole them '
#          'would love to know I made a donation to the #bidenharris2020 '
#          'campaign along with buying more signs #votehimout @joebiden '
#          '@kamalaharris #forthewin https://t.co/ORcjGEOe3c',
#  'user_mentions': [],
#  'userid': '45406060'}
# ********************************************************************************
# {'RT': False,
#  '_id': '1311066917130690561',
#  'created_at': {'date': '2020-09-29T22:14:46Z'},
#  'hashtags': [{'indices': [0, 9], 'text': 'BREAKING'}],
#  'lang': 'en',
#  'nRTin': 0,
#  'nquotein': 0,
#  'nreplyin': 0,
#  'quote': False,
#  'reply': False,
#  'screen_name': 'twright55',
#  'symbols': [],
#  'text': '#BREAKING: The Director of National Intelligence Ratcliffe has '
#          "declassified information indicating that former #Obama's "
#          'administration knew about #HillaryClinton was attempting to tie '
#          '#Trump to Russia and distract from her email scandal in 2016. He '
#          'plans to brief Congress ASAP.',
#  'user_mentions': [],
#  'userid': '93288759'}
# ********************************************************************************
# {'RT': True,
#  'RT_source': '1181007323759874048',
#  '_id': '1311067099465277440',
#  'checkRT': True,
#  'created_at': {'date': '2020-09-29T22:15:29Z'},
#  'lang': 'en',
#  'nRTin': 0,
#  'nquotein': 0,
#  'nreplyin': 0,
#  'quote': False,
#  'reply': False,
#  'screen_name': 'thgroundbeneath',
#  'userid': '13885772'}
# ********************************************************************************
# {'RT': False,
#  '_id': '1311073195282149376',
#  'created_at': {'date': '2020-09-29T22:39:42Z'},
#  'hashtags': [],
#  'in_reply_to_screen_name': 'JoeBiden',
#  'in_reply_to_status_id_str': '1310998525321383944',
#  'in_reply_to_user_id_str': '939091',
#  'lang': 'en',
#  'nRTin': 0,
#  'nquotein': 0,
#  'nreplyin': 0,
#  'quote': False,
#  'reply': True,
#  'screen_name': 'mastahanksta',
#  'symbols': [],
#  'text': '@JoeBiden Biden is going to be the President fir 2021 new '
#          'beginnings!',
#  'user_mentions': [{'id': 939091,
#                     'id_str': '939091',
#                     'indices': [0, 9],
#                     'name': 'Joe Biden',
#                     'screen_name': 'JoeBiden'}],
#  'userid': '24640148'}
# ********************************************************************************
# {'RT': True,
#  'RT_source': '1311070593043759104',
#  '_id': '1311074200187092992',
#  'checkRT': True,
#  'created_at': {'date': '2020-09-29T22:43:42Z'},
#  'lang': 'en',
#  'nRTin': 0,
#  'nquotein': 0,
#  'nreplyin': 0,
#  'quote': False,
#  'reply': False,
#  'screen_name': 'thgroundbeneath',
#  'userid': '13885772'}
# ********************************************************************************
# {'RT': False,
#  '_id': '1311074602244866058',
#  'created_at': {'date': '2020-09-29T22:45:18Z'},
#  'hashtags': [],
#  'lang': 'en',
#  'nRTin': 0,
#  'nquotein': 1,
#  'nreplyin': 0,
#  'quote': False,
#  'reply': False,
#  'screen_name': 'BGOnTheScene',
#  'symbols': [],
#  'text': 'A woman discusses being arrested for protesting in both Columbus and '
#          'Louisville, and how this impacts one’s ability to be out there on '
#          'the front lines every night #Debates2020\xa0 #DebateTuesday '
#          '#Cleveland https://t.co/FIuNA13CXx',
#  'user_mentions': [],
#  'userid': '23951440'}
# ********************************************************************************
# {'RT': False,
#  '_id': '1311075070148657152',
#  'created_at': {'date': '2020-09-29T22:47:09Z'},
#  'hashtags': [],
#  'lang': 'en',
#  'nRTin': 0,
#  'nquotein': 0,
#  'nreplyin': 0,
#  'quote': True,
#  'reply': False,
#  'screen_name': 'MyParExcellence',
#  'symbols': [],
#  'text': 'Isaiah 5:20 at its worst case!  @realDonaldTrump @GenFlynn '
#          '@SidneyPowell1 @ALT_DOJ @KerriKupecDOJ @DOJPH @thevivafrei '
#          '@marklevinshow @Barnes_Law @JudgeJeanine @TuckerCarlson '
#          '@RichardGrenell @greggutfeld @IngrahamAngle',
#  'user_mentions': [{'id': 25073877,
#                     'id_str': '25073877',
#                     'indices': [32, 48],
#                     'name': 'Donald J. Trump',
#                     'screen_name': 'realDonaldTrump'},
#                    {'id': 240454812,
#                     'id_str': '240454812',
#                     'indices': [49, 58],
#                     'name': 'General Flynn',
#                     'screen_name': 'GenFlynn'},
#                    {'id': 586707638,
#                     'id_str': '586707638',
#                     'indices': [59, 73],
#                     'name': 'Sidney Powell 🇺🇸⭐⭐⭐',
#                     'screen_name': 'SidneyPowell1'},
#                    {'id': 824450140131975168,
#                     'id_str': '824450140131975168',
#                     'indices': [74, 82],
#                     'name': 'ALT DOJ',
#                     'screen_name': 'ALT_DOJ'},
#                    {'id': 1062465792212717574,
#                     'id_str': '1062465792212717574',
#                     'indices': [83, 97],
#                     'name': 'Kerri Kupec DOJ',
#                     'screen_name': 'KerriKupecDOJ'},
#                    {'id': 485403686,
#                     'id_str': '485403686',
#                     'indices': [98, 104],
#                     'name': 'Department of Justice (DOJ)',
#                     'screen_name': 'DOJPH'}],
#  'userid': '161605938'}
# ********************************************************************************
# {'RT': False,
#  '_id': '1311081076924669953',
#  'coordinates': {'coordinates': [-81.03876114, 34.01119057], 'type': 'Point'},
#  'created_at': {'date': '2020-09-29T23:11:02Z'},
#  'hashtags': [],
#  'lang': 'en',
#  'nRTin': 0,
#  'nquotein': 0,
#  'nreplyin': 0,
#  'quote': False,
#  'reply': False,
#  'screen_name': 'LumberjackHill',
#  'symbols': [],
#  'text': '@realdonaldtrump lied on 12-Jun-2017 saying "Great success, '
#          "including MS-13. They're being thrown out in record numbers and "
#          "rapidly. And they're being depleted. They'll all be gone pretty "
#          'soon."  #RepublicansAgainstTrump',
#  'user_mentions': [{'id': 25073877,
#                     'id_str': '25073877',
#                     'indices': [0, 16],
#                     'name': 'Donald J. Trump',
#                     'screen_name': 'realDonaldTrump'}],
#  'userid': '826549394606546946'}
# ********************************************************************************
# {'RT': False,
#  '_id': '1311082919461564416',
#  'coordinates': {'coordinates': [-77.0387238, 38.8976805], 'type': 'Point'},
#  'created_at': {'date': '2020-09-29T23:18:21Z'},
#  'hashtags': [],
#  'in_reply_to_screen_name': 'PATrumpVictory',
#  'in_reply_to_status_id_str': '1311078153146609664',
#  'in_reply_to_user_id_str': '1017871914914721799',
#  'lang': 'en',
#  'nRTin': 0,
#  'nquotein': 0,
#  'nreplyin': 0,
#  'quote': False,
#  'reply': True,
#  'screen_name': 'DaysLeft4Trump',
#  'symbols': [],
#  'text': '@PATrumpVictory @Mike_Pence @realDonaldTrump 3 Months, 21 Days, 17 '
#          'Hours, 41 Minutes, and 53 Seconds',
#  'user_mentions': [{'id': 1017871914914721799,
#                     'id_str': '1017871914914721799',
#                     'indices': [0, 15],
#                     'name': 'Pennsylvania Trump Victory',
#                     'screen_name': 'PATrumpVictory'},
#                    {'id': 22203756,
#                     'id_str': '22203756',
#                     'indices': [16, 27],
#                     'name': 'Mike Pence',
#                     'screen_name': 'Mike_Pence'},
#                    {'id': 25073877,
#                     'id_str': '25073877',
#                     'indices': [28, 44],
#                     'name': 'Donald J. Trump',
#                     'screen_name': 'realDonaldTrump'}],
#  'userid': '822491959805825027'}
# ********************************************************************************
# {'RT': False,
#  '_id': '1311083380046401536',
#  'created_at': {'date': '2020-09-29T23:20:11Z'},
#  'hashtags': [],
#  'lang': 'en',
#  'nRTin': 0,
#  'nquotein': 0,
#  'nreplyin': 0,
#  'quote': False,
#  'reply': False,
#  'screen_name': 'HakimBe',
#  'symbols': [],
#  'text': "@JoeBiden Team, here'e a freebie. When he tries to pivot on his "
#          '"tax file" dysfunction and says you want to raise taxes (only on '
#          'those making more than 400K) ... say this, "We\'d never have to '
#          "raise taxes in this country if 'patriots' like you didn't "
#          'dodge\'em." #TaxDodger',
#  'user_mentions': [{'id': 939091,
#                     'id_str': '939091',
#                     'indices': [0, 9],
#                     'name': 'Joe Biden',
#                     'screen_name': 'JoeBiden'}],
#  'userid': '50925602'}
# ********************************************************************************
# {'RT': False,
#  '_id': '1311084580426985472',
#  'created_at': {'date': '2020-09-29T23:24:57Z'},
#  'hashtags': [{'indices': [40, 52], 'text': 'Debates2020'},
#               {'indices': [54, 68], 'text': 'DebateTuesday'},
#               {'indices': [69, 79], 'text': 'Cleveland'}],
#  'lang': 'en',
#  'nRTin': 0,
#  'nquotein': 1,
#  'nreplyin': 0,
#  'quote': False,
#  'reply': False,
#  'screen_name': 'BGOnTheScene',
#  'symbols': [],
#  'text': '“F*** Donald Trump” chants on the march #Debates2020\xa0 '
#          '#DebateTuesday #Cleveland https://t.co/BB2WmbOfCX',
#  'user_mentions': [],
#  'userid': '23951440'}
# ********************************************************************************
# {'RT': False,
#  '_id': '1311086812472004608',
#  'coordinates': {'coordinates': [-77.0387238, 38.8976805], 'type': 'Point'},
#  'created_at': {'date': '2020-09-29T23:33:49Z'},
#  'hashtags': [],
#  'in_reply_to_screen_name': 'WhiteHouse',
#  'in_reply_to_status_id_str': '1311086701561995265',
#  'in_reply_to_user_id_str': '822215673812119553',
#  'lang': 'en',
#  'nRTin': 1,
#  'nquotein': 0,
#  'nreplyin': 0,
#  'quote': False,
#  'reply': True,
#  'screen_name': 'DaysLeft4Trump',
#  'symbols': [],
#  'text': '@WhiteHouse @USDA @realDonaldTrump 3 Months, 21 Days, 17 Hours, 26 '
#          'Minutes, and 31 Seconds',
#  'user_mentions': [{'id': 822215673812119553,
#                     'id_str': '822215673812119553',
#                     'indices': [0, 11],
#                     'name': 'The White House',
#                     'screen_name': 'WhiteHouse'},
#                    {'id': 61853389,
#                     'id_str': '61853389',
#                     'indices': [12, 17],
#                     'name': 'Dept. of Agriculture',
#                     'screen_name': 'USDA'},
#                    {'id': 25073877,
#                     'id_str': '25073877',
#                     'indices': [18, 34],
#                     'name': 'Donald J. Trump',
#                     'screen_name': 'realDonaldTrump'}],
#  'userid': '822491959805825027'}
# ********************************************************************************
# {'RT': False,
#  '_id': '1311089122531049474',
#  'created_at': {'date': '2020-09-29T23:43:00Z'},
#  'hashtags': [{'indices': [20, 26], 'text': 'Trump'},
#               {'indices': [59, 71], 'text': 'Debates2020'},
#               {'indices': [72, 80], 'text': 'Debates'},
#               {'indices': [81, 100], 'text': 'PresidentialDebate'},
#               {'indices': [101, 108], 'text': 'Debate'}],
#  'lang': 'en',
#  'nRTin': 0,
#  'nquotein': 0,
#  'nreplyin': 0,
#  'quote': True,
#  'reply': False,
#  'screen_name': 'PhillyPartTwo',
#  'symbols': [],
#  'text': "They're mad because #Trump can't even afford Turkey Hill. \n"
#          '#Debates2020 #Debates #PresidentialDebate #Debate',
#  'user_mentions': [],
#  'userid': '108416118'}
# ********************************************************************************
# {'RT': False,
#  '_id': '1311092035697471489',
#  'created_at': {'date': '2020-09-29T23:54:34Z'},
#  'hashtags': [],
#  'lang': 'en',
#  'nRTin': 0,
#  'nquotein': 1,
#  'nreplyin': 1,
#  'quote': False,
#  'reply': False,
#  'screen_name': 'LionelMedia',
#  'symbols': [],
#  'text': 'What are you thinking right now regarding the upcoming debate?',
#  'user_mentions': [],
#  'userid': '24787367'}
# ********************************************************************************
# {'RT': False,
#  '_id': '1311095042891812866',
#  'created_at': {'date': '2020-09-30T00:06:31Z'},
#  'hashtags': [],
#  'lang': 'en',
#  'nRTin': 9,
#  'nquotein': 1,
#  'nreplyin': 1,
#  'quote': False,
#  'reply': False,
#  'screen_name': 'LionelMedia',
#  'symbols': [],
#  'text': '@realDonaldTrump must never answer any question but make a speech '
#          'every time he has the chance.',
#  'user_mentions': [{'id': 25073877,
#                     'id_str': '25073877',
#                     'indices': [0, 16],
#                     'name': 'Donald J. Trump',
#                     'screen_name': 'realDonaldTrump'}],
#  'userid': '24787367'}
# ********************************************************************************
# {'RT': True,
#  'RT_source': '1311094977922039809',
#  '_id': '1311095350610984960',
#  'checkRT': True,
#  'created_at': {'date': '2020-09-30T00:07:45Z'},
#  'lang': 'en',
#  'nRTin': 0,
#  'nquotein': 0,
#  'nreplyin': 0,
#  'quote': False,
#  'reply': False,
#  'screen_name': 'thgroundbeneath',
#  'userid': '13885772'}
# ********************************************************************************
# {'RT': True,
#  'RT_source': '1311077341355864064',
#  '_id': '1311095986614398976',
#  'checkRT': True,
#  'created_at': {'date': '2020-09-30T00:10:16Z'},
#  'lang': 'en',
#  'nRTin': 0,
#  'nquotein': 0,
#  'nreplyin': 0,
#  'quote': False,
#  'reply': False,
#  'screen_name': 'Truactive',
#  'userid': '277810122'}
# ********************************************************************************
# {'RT': True,
#  'RT_source': '1311083331325513729',
#  '_id': '1311096122732093441',
#  'checkRT': True,
#  'created_at': {'date': '2020-09-30T00:10:49Z'},
#  'lang': 'en',
#  'nRTin': 0,
#  'nquotein': 0,
#  'nreplyin': 0,
#  'quote': False,
#  'reply': False,
#  'screen_name': 'Truactive',
#  'userid': '277810122'}
# ********************************************************************************
# {'RT': False,
#  '_id': '1311096410994028544',
#  'created_at': {'date': '2020-09-30T00:11:58Z'},
#  'hashtags': [],
#  'lang': 'en',
#  'nRTin': 0,
#  'nquotein': 0,
#  'nreplyin': 0,
#  'quote': False,
#  'reply': False,
#  'screen_name': 'MikeKillmon',
#  'symbols': [],
#  'text': 'I know that @JoeBiden is gonna MAKE IT HAPPEN!!!! 💙🇺🇸 cc '
#          '@MariahCarey https://t.co/4s6gDkVV2D',
#  'user_mentions': [{'id': 939091,
#                     'id_str': '939091',
#                     'indices': [12, 21],
#                     'name': 'Joe Biden',
#                     'screen_name': 'JoeBiden'},
#                    {'id': 19248106,
#                     'id_str': '19248106',
#                     'indices': [57, 69],
#                     'name': 'Mariah Carey',
#                     'screen_name': 'MariahCarey'}],
#  'userid': '16263931'}
# ********************************************************************************
# {'RT': False,
#  '_id': '1311096449292218368',
#  'coordinates': {'coordinates': [-73.9675, 40.7779], 'type': 'Point'},
#  'created_at': {'date': '2020-09-30T00:12:07Z'},
#  'hashtags': [{'indices': [18, 28], 'text': 'superbowl'},
#               {'indices': [29, 33], 'text': 'nyc'},
#               {'indices': [35, 41], 'text': 'trump'},
#               {'indices': [42, 58], 'text': 'bidenharris2020'},
#               {'indices': [59, 65], 'text': 'lgbtq'},
#               {'indices': [66, 70], 'text': 'cnn'},
#               {'indices': [71, 80], 'text': 'instagay'},
#               {'indices': [81, 86], 'text': 'hope'},
#               {'indices': [87, 98], 'text': 'drumptrump'},
#               {'indices': [99, 106], 'text': 'riseup'}],
#  'lang': 'en',
#  'nRTin': 0,
#  'nquotein': 0,
#  'nreplyin': 0,
#  'quote': False,
#  'reply': False,
#  'screen_name': 'joshuatowevoice',
#  'symbols': [],
#  'text': 'Getting ready for #superbowl #nyc  #trump #bidenharris2020 #lgbtq '
#          '#cnn #instagay #hope #drumptrump #riseup #thisisus #nytimes #love '
#          '#goodbyetrump @ Manhattan, New York https://t.co/YGAQyZkKdq',
#  'user_mentions': [],
#  'userid': '3360903167'}
# ********************************************************************************
# {'RT': False,
#  '_id': '1311101607283752962',
#  'coordinates': {'coordinates': [-77.0387238, 38.8976805], 'type': 'Point'},
#  'created_at': {'date': '2020-09-30T00:32:36Z'},
#  'hashtags': [],
#  'in_reply_to_screen_name': 'Mike_Pence',
#  'in_reply_to_status_id_str': '1311101462642999297',
#  'in_reply_to_user_id_str': '22203756',
#  'lang': 'en',
#  'nRTin': 0,
#  'nquotein': 0,
#  'nreplyin': 0,
#  'quote': False,
#  'reply': True,
#  'screen_name': 'DaysLeft4Trump',
#  'symbols': [],
#  'text': '@Mike_Pence @realDonaldTrump @WhiteHouse 3 Months, 21 Days, 16 '
#          'Hours, 27 Minutes, and 52 Seconds',
#  'user_mentions': [{'id': 22203756,
#                     'id_str': '22203756',
#                     'indices': [0, 11],
#                     'name': 'Mike Pence',
#                     'screen_name': 'Mike_Pence'},
#                    {'id': 25073877,
#                     'id_str': '25073877',
#                     'indices': [12, 28],
#                     'name': 'Donald J. Trump',
#                     'screen_name': 'realDonaldTrump'},
#                    {'id': 822215673812119553,
#                     'id_str': '822215673812119553',
#                     'indices': [29, 40],
#                     'name': 'The White House',
#                     'screen_name': 'WhiteHouse'}],
#  'userid': '822491959805825027'}
# ********************************************************************************
# {'RT': True,
#  'RT_source': '1311087116198305792',
#  '_id': '1311101965376643074',
#  'checkRT': True,
#  'created_at': {'date': '2020-09-30T00:34:02Z'},
#  'lang': 'en',
#  'nRTin': 0,
#  'nquotein': 0,
#  'nreplyin': 0,
#  'quote': False,
#  'reply': False,
#  'screen_name': 'jackilyden',
#  'userid': '235874933'}
# ********************************************************************************
# {'RT': False,
#  '_id': '1311102510724251649',
#  'coordinates': {'coordinates': [-82.7672, 28.0777], 'type': 'Point'},
#  'created_at': {'date': '2020-09-30T00:36:12Z'},
#  'hashtags': [{'indices': [36, 52], 'text': 'bidenharris2020'},
#               {'indices': [53, 66], 'text': 'voteblue2020'},
#               {'indices': [67, 77], 'text': 'dumptrump'},
#               {'indices': [78, 90], 'text': 'enhancethis'}],
#  'lang': 'en',
#  'nRTin': 0,
#  'nquotein': 0,
#  'nreplyin': 0,
#  'quote': False,
#  'reply': False,
#  'screen_name': 'Mdepaul76',
#  'symbols': [],
#  'text': 'I’m ready ! Let’s do this @joebiden #bidenharris2020 #voteblue2020 '
#          '#dumptrump #enhancethis @ Palm Harbor, Florida '
#          'https://t.co/eEU3foYdVq',
#  'user_mentions': [{'id': 939091,
#                     'id_str': '939091',
#                     'indices': [26, 35],
#                     'name': 'Joe Biden',
#                     'screen_name': 'JoeBiden'}],
#  'userid': '37174314'}
# ********************************************************************************
# {'RT': False,
#  '_id': '1311104782556442625',
#  'created_at': {'date': '2020-09-30T00:45:13Z'},
#  'hashtags': [],
#  'lang': 'en',
#  'nRTin': 2,
#  'nquotein': 0,
#  'nreplyin': 1,
#  'quote': False,
#  'reply': False,
#  'screen_name': 'LionelMedia',
#  'symbols': [],
#  'text': 'You’re about to witness polemic savagery. Unyielding and unrelenting '
#          'brutality in the name of liberty and truth. Go get him, '
#          '@realDonaldTrump. https://t.co/muuGxVmbte',
#  'user_mentions': [],
#  'userid': '24787367'}
# ********************************************************************************
# {'RT': False,
#  '_id': '1311105904734015488',
#  'created_at': {'date': '2020-09-30T00:49:41Z'},
#  'hashtags': [],
#  'lang': 'en',
#  'nRTin': 1,
#  'nquotein': 0,
#  'nreplyin': 0,
#  'quote': True,
#  'reply': False,
#  'screen_name': 'shiffy64',
#  'symbols': [],
#  'text': 'Fact check @the truth https://t.co/jN0K0m0ecA',
#  'user_mentions': [{'id': 25668422,
#                     'id_str': '25668422',
#                     'indices': [11, 15],
#                     'name': 'Тајлер',
#                     'screen_name': 'the'}],
#  'userid': '24515539'}
# ********************************************************************************
# {'RT': False,
#  '_id': '1311107752236740610',
#  'coordinates': {'coordinates': [-81.38340354, 28.54389942], 'type': 'Point'},
#  'created_at': {'date': '2020-09-30T00:57:01Z'},
#  'hashtags': [],
#  'lang': 'en',
#  'nRTin': 0,
#  'nquotein': 0,
#  'nreplyin': 0,
#  'quote': False,
#  'reply': False,
#  'screen_name': 'LumberjackHill',
#  'symbols': [],
#  'text': '@realdonaldtrump lied on 03-Nov-2018 saying "We\'ve taken the '
#          "toughest ever action to crack down on China's very abusive trade "
#          'practices, and now they\'re paying big tariffs on 250 billion..." '
#          '#RepublicansForBiden',
#  'user_mentions': [{'id': 25073877,
#                     'id_str': '25073877',
#                     'indices': [0, 16],
#                     'name': 'Donald J. Trump',
#                     'screen_name': 'realDonaldTrump'}],
#  'userid': '826549394606546946'}
# ********************************************************************************
# {'RT': True,
#  'RT_source': '1311107932348506112',
#  '_id': '1311108097897828353',
#  'checkRT': True,
#  'created_at': {'date': '2020-09-30T00:58:24Z'},
# ...
#                     'id_str': '25073877',
#                     'indices': [46, 62],
#                     'name': 'Donald J. Trump',
#                     'screen_name': 'realDonaldTrump'}],
#  'userid': '63335631'}
# ********************************************************************************
# {'RT': False,
#  '_id': '1311112681017860097',
#  'created_at': {'date': '2020-09-30T01:16:37Z'},
#  'hashtags': [],
#  'lang': 'en',
#  'nRTin': 29,
#  'nquotein': 0,
#  'nreplyin': 5,
#  'quote': False,
#  'reply': False,
#  'screen_name': 'Joy_Villa',
#  'symbols': [],
#  'text': 'CHRIS WASN’T READY FOR THE DRAGON ENERGY OF @realDonaldTrump !!!',
#  'user_mentions': [{'id': 25073877,
#                     'id_str': '25073877',
#                     'indices': [44, 60],
#                     'name': 'Donald J. Trump',
#                     'screen_name': 'realDonaldTrump'}],
#  'userid': '63335631'}
# ********************************************************************************
# {'RT': False,
#  '_id': '1311114009811316736',
#  'created_at': {'date': '2020-09-30T01:21:53Z'},
#  'hashtags': [],
#  'lang': 'en',
#  'nRTin': 20,
#  'nquotein': 2,
#  'nreplyin': 2,
#  'quote': False,
#  'reply': False,
#  'screen_name': 'LionelMedia',
#  'symbols': [],
#  'text': '“Will you shut up, man!” That’s it. You’ve got under his skin, '
#          '@realDonaldTrump.',
#  'user_mentions': [{'id': 25073877,
#                     'id_str': '25073877',
#                     'indices': [63, 79],
#                     'name': 'Donald J. Trump',
#                     'screen_name': 'realDonaldTrump'}],
#  'userid': '24787367'}
# ********************************************************************************
# {'RT': False,
#  '_id': '1311114259489787905',
#  'created_at': {'date': '2020-09-30T01:22:53Z'},
#  'hashtags': [{'indices': [0, 7], 'text': 'debate'},
#               {'indices': [8, 20], 'text': 'Debates2020'},
#               {'indices': [25, 40], 'text': 'MitchMcConnell'},
#               {'indices': [81, 87], 'text': 'Trump'}],
#  'lang': 'en',
#  'nRTin': 1,
#  'nquotein': 0,
#  'nreplyin': 0,
#  'quote': False,
#  'reply': False,
#  'screen_name': 'twright55',
#  'symbols': [],
#  'text': '#debate #Debates2020 why #MitchMcConnell made a statement last year '
#          'knowing that #Trump did nothing wrong with Ukraine phone call took '
#          'articles of impeachment to the Senate Floor? To make Pence Pres? Who '
#          'lobbied Mitch? Never Trumpers from BGR Group? Should they be '
#          'investigated? https://t.co/40FTAP7o7g',
#  'user_mentions': [],
#  'userid': '93288759'}
# ********************************************************************************
# {'RT': False,
#  '_id': '1311114557864267777',
#  'coordinates': {'coordinates': [-77.0387238, 38.8976805], 'type': 'Point'},
#  'created_at': {'date': '2020-09-30T01:24:04Z'},
#  'hashtags': [],
#  'in_reply_to_screen_name': 'KellyannePolls',
#  'in_reply_to_status_id_str': '1311114363558940679',
#  'in_reply_to_user_id_str': '471672239',
#  'lang': 'en',
#  'nRTin': 2,
#  'nquotein': 0,
#  'nreplyin': 0,
#  'quote': False,
#  'reply': True,
#  'screen_name': 'DaysLeft4Trump',
#  'symbols': [],
#  'text': '@KellyannePolls @realDonaldTrump @JoeBiden 3 Months, 21 Days, 15 '
#          'Hours, 36 Minutes, and 36 Seconds',
#  'user_mentions': [{'id': 471672239,
#                     'id_str': '471672239',
#                     'indices': [0, 15],
#                     'name': 'Kellyanne Conway',
#                     'screen_name': 'KellyannePolls'},
#                    {'id': 25073877,
#                     'id_str': '25073877',
#                     'indices': [16, 32],
#                     'name': 'Donald J. Trump',
#                     'screen_name': 'realDonaldTrump'},
#                    {'id': 939091,
#                     'id_str': '939091',
#                     'indices': [33, 42],
#                     'name': 'Joe Biden',
#                     'screen_name': 'JoeBiden'}],
#  'userid': '822491959805825027'}
# ********************************************************************************
# {'RT': True,
#  'RT_source': '1311113450572185601',
#  '_id': '1311114759891120128',
#  'checkRT': True,
#  'created_at': {'date': '2020-09-30T01:24:52Z'},
#  'lang': 'en',
#  'nRTin': 0,
#  'nquotein': 0,
#  'nreplyin': 0,
#  'quote': False,
#  'reply': False,
#  'screen_name': 'MyParExcellence',
#  'userid': '161605938'}
# ********************************************************************************
# {'RT': True,
#  'RT_source': '1311113985090113537',
#  '_id': '1311114923129405440',
#  'checkRT': True,
#  'created_at': {'date': '2020-09-30T01:25:31Z'},
#  'lang': 'en',
#  'nRTin': 0,
#  'nquotein': 0,
#  'nreplyin': 0,
#  'quote': False,
#  'reply': False,
#  'screen_name': 'MikeKillmon',
#  'userid': '16263931'}
# ********************************************************************************
# {'RT': False,
#  '_id': '1311115120773337089',
#  'coordinates': {'coordinates': [-77.0387238, 38.8976805], 'type': 'Point'},
#  'created_at': {'date': '2020-09-30T01:26:18Z'},
#  'hashtags': [],
#  'in_reply_to_screen_name': 'KellyannePolls',
#  'in_reply_to_status_id_str': '1311114989588156416',
#  'in_reply_to_user_id_str': '471672239',
#  'lang': 'en',
#  'nRTin': 3,
#  'nquotein': 0,
#  'nreplyin': 0,
#  'quote': False,
#  'reply': True,
#  'screen_name': 'DaysLeft4Trump',
#  'symbols': [],
#  'text': '@KellyannePolls @JoeBiden 3 Months, 21 Days, 15 Hours, 34 Minutes, '
#          'and 7 Seconds',
#  'user_mentions': [{'id': 471672239,
#                     'id_str': '471672239',
#                     'indices': [0, 15],
#                     'name': 'Kellyanne Conway',
#                     'screen_name': 'KellyannePolls'},
#                    {'id': 939091,
#                     'id_str': '939091',
#                     'indices': [16, 25],
#                     'name': 'Joe Biden',
#                     'screen_name': 'JoeBiden'}],
#  'userid': '822491959805825027'}
# ********************************************************************************
# {'RT': False,
#  '_id': '1311115167279779841',
#  'created_at': {'date': '2020-09-30T01:26:29Z'},
#  'hashtags': [{'indices': [58, 64], 'text': 'Trump'},
#               {'indices': [93, 105], 'text': 'Debates2020'},
#               {'indices': [106, 114], 'text': 'Debates'}],
#  'lang': 'en',
#  'nRTin': 0,
#  'nquotein': 0,
#  'nreplyin': 0,
#  'quote': False,
#  'reply': False,
#  'screen_name': 'PhillyPartTwo',
#  'symbols': [],
#  'text': 'For someone who "doesn\'t care" about what the media says, #Trump '
#          'seems to bring it up a lot. #Debates2020 #Debates',
#  'user_mentions': [],
#  'userid': '108416118'}
# ********************************************************************************
# {'RT': True,
#  'RT_source': '1311113873907474433',
#  '_id': '1311115494720667653',
#  'checkRT': True,
#  'created_at': {'date': '2020-09-30T01:27:47Z'},
#  'lang': 'en',
#  'nRTin': 0,
#  'nquotein': 0,
#  'nreplyin': 0,
#  'quote': False,
#  'reply': False,
#  'screen_name': 'Truactive',
#  'userid': '277810122'}
# ********************************************************************************
# {'RT': True,
#  'RT_source': '1311115397832282112',
#  '_id': '1311115733758291971',
#  'checkRT': True,
#  'created_at': {'date': '2020-09-30T01:28:44Z'},
#  'lang': 'en',
#  'nRTin': 0,
#  'nquotein': 0,
#  'nreplyin': 0,
#  'quote': False,
#  'reply': False,
#  'screen_name': 'kfjelsted',
#  'userid': '16608462'}
# ********************************************************************************
# {'RT': False,
#  '_id': '1311115926071279616',
#  'coordinates': {'coordinates': [-77.0387238, 38.8976805], 'type': 'Point'},
#  'created_at': {'date': '2020-09-30T01:29:30Z'},
#  'hashtags': [],
#  'in_reply_to_screen_name': 'TayFromCA',
#  'in_reply_to_status_id_str': '1311113512530321410',
#  'in_reply_to_user_id_str': '1133393084807618560',
#  'lang': 'en',
#  'nRTin': 0,
#  'nquotein': 0,
#  'nreplyin': 0,
#  'quote': False,
#  'reply': True,
#  'screen_name': 'DaysLeft4Trump',
#  'symbols': [],
#  'text': '@TayFromCA @DonaldJTrumpJr @realDonaldTrump 3 Months, 21 Days, 15 '
#          'Hours, 31 Minutes, and 19 Seconds',
#  'user_mentions': [{'id': 1133393084807618560,
#                     'id_str': '1133393084807618560',
#                     'indices': [0, 10],
#                     'name': 'Taylor Budowich',
#                     'screen_name': 'TayFromCA'},
#                    {'id': 39344374,
#                     'id_str': '39344374',
#                     'indices': [11, 26],
#                     'name': 'Donald Trump Jr.',
#                     'screen_name': 'DonaldJTrumpJr'},
#                    {'id': 25073877,
#                     'id_str': '25073877',
#                     'indices': [27, 43],
#                     'name': 'Donald J. Trump',
#                     'screen_name': 'realDonaldTrump'}],
#  'userid': '822491959805825027'}
# ********************************************************************************
# {'RT': False,
#  '_id': '1311116047718780929',
#  'created_at': {'date': '2020-09-30T01:29:59Z'},
#  'hashtags': [{'indices': [63, 75], 'text': 'Debates2020'}],
#  'lang': 'en',
#  'nRTin': 0,
#  'nquotein': 0,
#  'nreplyin': 1,
#  'quote': False,
#  'reply': False,
#  'screen_name': 'KamauMccray',
#  'symbols': [],
#  'text': '@joebiden has to stop letting @realdonaldtrump interrupt him.\n'
#          '\n'
#          '#Debates2020',
#  'user_mentions': [{'id': 939091,
#                     'id_str': '939091',
#                     'indices': [0, 9],
#                     'name': 'Joe Biden',
#                     'screen_name': 'JoeBiden'},
#                    {'id': 25073877,
#                     'id_str': '25073877',
#                     'indices': [30, 46],
#                     'name': 'Donald J. Trump',
#                     'screen_name': 'realDonaldTrump'}],
#  'userid': '35959588'}
# ********************************************************************************
# {'RT': False,
#  '_id': '1311116245203288066',
#  'created_at': {'date': '2020-09-30T01:30:46Z'},
#  'hashtags': [],
#  'lang': 'en',
#  'nRTin': 0,
#  'nquotein': 0,
#  'nreplyin': 0,
#  'quote': True,
#  'reply': False,
#  'screen_name': 'nrsantilli',
#  'symbols': [],
#  'text': 'Trump is lying about his statements on China.',
#  'user_mentions': [],
#  'userid': '254997988'}
# ********************************************************************************
# {'RT': False,
#  '_id': '1311116748524056577',
#  'created_at': {'date': '2020-09-30T01:32:46Z'},
#  'hashtags': [],
#  'lang': 'en',
#  'nRTin': 0,
#  'nquotein': 0,
#  'nreplyin': 0,
#  'quote': False,
#  'reply': False,
#  'screen_name': 'SeamusCampbell',
#  'symbols': [],
#  'text': '.@realDonaldTrump is talking about academics. I’m not asking my '
#          'fellow Fordham Rams to break FERPA but I’m also not not saying that.',
#  'user_mentions': [{'id': 25073877,
#                     'id_str': '25073877',
#                     'indices': [1, 17],
#                     'name': 'Donald J. Trump',
#                     'screen_name': 'realDonaldTrump'}],
#  'userid': '24999101'}
# ********************************************************************************
# {'RT': True,
#  'RT_source': '1311114470974992388',
#  '_id': '1311116760905547776',
#  'checkRT': True,
#  'created_at': {'date': '2020-09-30T01:32:49Z'},
#  'lang': 'en',
#  'nRTin': 0,
#  'nquotein': 0,
#  'nreplyin': 0,
#  'quote': False,
#  'reply': False,
#  'screen_name': 'jammyprod',
#  'userid': '36628828'}
# ********************************************************************************
# {'RT': True,
#  'RT_source': '1311116745210392576',
#  '_id': '1311116907525951488',
#  'checkRT': True,
#  'created_at': {'date': '2020-09-30T01:33:24Z'},
#  'lang': 'en',
#  'nRTin': 0,
#  'nquotein': 0,
#  'nreplyin': 0,
#  'quote': False,
#  'reply': False,
#  'screen_name': 'RosiePaulsen',
#  'userid': '498172726'}
# ********************************************************************************
# {'RT': True,
#  'RT_source': '1311116612242681857',
#  '_id': '1311117201588596739',
#  'checkRT': True,
#  'created_at': {'date': '2020-09-30T01:34:34Z'},
#  'lang': 'en',
#  'nRTin': 0,
#  'nquotein': 0,
#  'nreplyin': 0,
#  'quote': False,
#  'reply': False,
#  'screen_name': 'kfjelsted',
#  'userid': '16608462'}
# ********************************************************************************
# {'RT': True,
#  'RT_source': '1311116576637190145',
#  '_id': '1311117494778814464',
#  'checkRT': True,
#  'created_at': {'date': '2020-09-30T01:35:44Z'},
#  'lang': 'en',
#  'nRTin': 0,
#  'nquotein': 0,
#  'nreplyin': 0,
#  'quote': False,
#  'reply': False,
#  'screen_name': 'KamauMccray',
#  'userid': '35959588'}
# ********************************************************************************
# {'RT': True,
#  'RT_source': '1311117106096742400',
#  '_id': '1311117523602018304',
#  'checkRT': True,
#  'created_at': {'date': '2020-09-30T01:35:51Z'},
#  'lang': 'en',
#  'nRTin': 0,
#  'nquotein': 0,
#  'nreplyin': 0,
#  'quote': False,
#  'reply': False,
#  'screen_name': 'kfjelsted',
#  'userid': '16608462'}
# ********************************************************************************
# {'RT': False,
#  '_id': '1311117616992452608',
#  'created_at': {'date': '2020-09-30T01:36:13Z'},
#  'hashtags': [],
#  'lang': 'en',
#  'nRTin': 0,
#  'nquotein': 0,
#  'nreplyin': 0,
#  'quote': False,
#  'reply': False,
#  'screen_name': 'fancybob',
#  'symbols': [],
#  'text': 'Can someone please get a message to @JoeBiden to IGNORE Drumpf when '
#          "he cuts in??? He's letting him hijack the conversation, &amp; it "
#          "actually pisses off Drumpf more when he's just ignored\n"
#          '\n'
#          '#Debates2020 #PresidentialDebate2020 #PresidentialDebate @TeamJoe '
#          '@truth #VoteBlueToSaveAmerica',
#  'user_mentions': [{'id': 939091,
#                     'id_str': '939091',
#                     'indices': [36, 45],
#                     'name': 'Joe Biden',
#                     'screen_name': 'JoeBiden'}],
#  'userid': '30230585'}
# ********************************************************************************
# {'RT': True,
#  'RT_source': '1311115554212675584',
#  '_id': '1311117717102096385',
#  'checkRT': True,
#  'created_at': {'date': '2020-09-30T01:36:37Z'},
#  'lang': 'en',
#  'nRTin': 0,
#  'nquotein': 0,
#  'nreplyin': 0,
#  'quote': False,
#  'reply': False,
#  'screen_name': 'MikeKillmon',
#  'userid': '16263931'}
# ********************************************************************************
# {'RT': True,
#  'RT_source': '1311116998638735367',
#  '_id': '1311117847133696000',
#  'checkRT': True,
#  'created_at': {'date': '2020-09-30T01:37:08Z'},
#  'lang': 'en',
#  'nRTin': 0,
#  'nquotein': 0,
#  'nreplyin': 0,
#  'quote': False,
#  'reply': False,
#  'screen_name': 'kfjelsted',
#  'userid': '16608462'}
# ********************************************************************************
# {'RT': True,
#  'RT_source': '1311118155515789312',
#  '_id': '1311118207537876992',
#  'checkRT': True,
#  'created_at': {'date': '2020-09-30T01:38:34Z'},
#  'lang': 'en',
#  'nRTin': 0,
#  'nquotein': 0,
#  'nreplyin': 0,
#  'quote': False,
#  'reply': False,
#  'screen_name': 'kfjelsted',
#  'userid': '16608462'}
# ********************************************************************************
# {'RT': True,
#  'RT_source': '1311117686601060359',
#  '_id': '1311118384021549057',
#  'checkRT': True,
#  'created_at': {'date': '2020-09-30T01:39:16Z'},
#  'lang': 'en',
#  'nRTin': 0,
#  'nquotein': 0,
#  'nreplyin': 0,
#  'quote': False,
#  'reply': False,
#  'screen_name': 'kfjelsted',
#  'userid': '16608462'}
# ********************************************************************************
# {'RT': False,
#  '_id': '1311120440790839296',
#  'created_at': {'date': '2020-09-30T01:47:27Z'},
#  'hashtags': [{'indices': [59, 78], 'text': 'PresidentialDebate'}],
#  'lang': 'en',
#  'nRTin': 1,
#  'nquotein': 0,
#  'nreplyin': 0,
#  'quote': False,
#  'reply': False,
#  'screen_name': 'DrJCottrell',
#  'symbols': [],
#  'text': '“And the economy is busted!” @JoeBiden to @realDonaldTrump '
#          '#PresidentialDebate',
#  'user_mentions': [{'id': 939091,
#                     'id_str': '939091',
#                     'indices': [29, 38],
#                     'name': 'Joe Biden',
#                     'screen_name': 'JoeBiden'},
#                    {'id': 25073877,
#                     'id_str': '25073877',
#                     'indices': [42, 58],
#                     'name': 'Donald J. Trump',
#                     'screen_name': 'realDonaldTrump'}],
#  'userid': '207602580'}
# ********************************************************************************

# %% [markdown]
# **Ejercicio 0** Escribir una función `lenguajes` que devuelva cuántos tweets están escritos en un idioma
# (clave `lang`) concreto.
#
# - *Nombre*: `lenguajes`
# - *Parámetros de entrada*:
#     - `db`: el acceso a una base de datos que se asume incluye una colección `tweet`de tweets
#     - `lenguaje`: código en twitter indicando el lenguaje
#
# - *Devuelve*: número de tweets que son réplicas al usuario (un entero mayor o igual que 0)

# %%
# solución
def lenguajes(db, lenguaje):
    return db.tweet.count_documents({"lang": lenguaje})


### para probar el código
print(lenguajes(db, "en"), " tweets en inglés")
print(lenguajes(db, "es"), " tweets en castellano")
# Out:
# 3015  tweets en inglés
# 0  tweets en castellano

# %% [markdown]
# **Ejercicio 1** Escribir una función `num_replicas` que devuelva cuántos tweets son respuestas, o réplicas (clave `in_reply_to_screen_name`) a un usuario.
#
# - *Nombre*: `num_replicas`
# - *Parámetros de entrada*:
#     - `db`: el acceso a una base de datos que se asume incluye una colección `tweet`de tweets
#     - `usuario`: screen_name de un usuario
#
# - *Devuelve*: número de tweets que son réplicas al usuario (un entero mayor o igual que 0)
#
# Salida esperada:
#
#         25 réplicas a JoeBiden
#         204 réplicas a realDonaldTrump

# %%
# solución
def num_replicas(db, usuario):
    return db.tweet.count_documents({"in_reply_to_screen_name": usuario})


### para probar el código
print(num_replicas(db, "JoeBiden"), "réplicas a JoeBiden")
print(num_replicas(db, "realDonaldTrump"), "réplicas a realDonaldTrump")
# Out:
# 25 réplicas a JoeBiden
# 204 réplicas a realDonaldTrump

# %% [markdown]
# **Ejercicio 2** Escribir una función `num_menciones` para conocer el número de tweets que nombran (examinar `user_mentions`) a un usuario dado su `screen_name`
# - *Nombre*: `num_menciones`
# - *Parámetros de entrada*:
#     - `db`: el acceso a una base de datos que se asume incluye una colección `tweet`de tweets
#     - `usuario`: screen_name de un usuario
#
# - *Devuelve*: número de tweets que mencionan al usuario (un entero mayor o igual a 0)
#
# Salida esperada:
#
#     453 menciones a JoeBiden
#     1479 menciones a realDonaldTrump

# %%
# solución
def num_menciones(db, usuario):
    return db.tweet.count_documents({"user_mentions.screen_name": usuario})


### para probar el código
print(num_menciones(db, "JoeBiden"), "menciones a JoeBiden")
print(num_menciones(db, "realDonaldTrump"), "menciones a realDonaldTrump")
# Out:
# 453 menciones a JoeBiden
# 1479 menciones a realDonaldTrump

# %% [markdown]
# **Ejercicio 3** Escribir una función `citas_posteriores_a` que muestre el número de tweets que son citas (clave `quote` a True), y que se hayan emitido con posterioridad a una fecha dada
#
# - *Nombre*: `citas_posteriores_a`
# - *Parámetros de entrada*:
#     - `db`: el acceso a una base de datos que se asume incluye una colección `tweet`de tweets
#     - `fecha`: un string con la fecha en el formato que se usa en este dataset
#
# - *Devuelve*: Número de tweets con `quote` a True emitidos con fecha posterior a la indicada
#
# - Obs:  Para verificar que la fecha es posterior no hay que hacer ninguna conversión ni nada similar, solo comparar la fecha de creación del tweet (clave `date` de `created_at`) con el operador la representación en Mongo del operador >.
#
# Salida esperada: 300

# %%
def citas_posteriores_a(db, fecha):
    return db.tweet.count_documents({"quote": True, "created_at.date": {"$gt": fecha}})


citas_posteriores_a(db, "2020-09-24T12:49:01Z")
# Out:
# 300

# %% [markdown]
# **Ejercicio 4** Escribir una función `prop_clave` para conocer la proporción de documentos que contienen una cierta clave a primer nivel en la colección tweets
# - *Nombre*: `prop_clave`
# - *Parámetros de entrada*:
#     - `db`: el acceso a una base de datos que se asume incluye una colección `tweet`de tweets
#     - `clave`: clave a comprobar
#
# - *Devuelve*: proporción sobre 1 (número entre 0 y 1) de tweets que incluyen la clave
# - Obs: se puede usar python para hacer la operación aritmética que da la proporción, no tiene sentido usar MongoDB para eso
#
# En el ejemplo se prueba la prop. de tweets que tienen coordenadas (esto es incluyen la clave 'coordinates')
#
# Ayuda: consultar información del operador [$exists](https://docs.mongodb.com/manual/reference/operator/query/exists/) (recordar que en pymongo hay que poner el nombre entre comillas)
#
# Salida esperada:
#
#         Proporción de tweets con coordenadas 0.6

# %%
def prop_clave(db, clave):
    return db.tweet.count_documents(
        {clave: {"$exists": True}}
    ) / db.tweet.count_documents({})


print("Proporción de tweets con coordenadas", round(prop_clave(db, "coordinates"), 2))
# Out:
# Proporción de tweets con coordenadas 0.6

# %% [markdown]
# **Ejercicio 5** Escribir una función `retuiteados` que crea una lista con los `screen_name` de los usuarios que han enviado tweets que tienen al menos un cierto número de retweets (clave nRTin mayor que un valor).
#
# - *Nombre*: `retuiteados`
# - *Parámetros de entrada*:
#     - `db`: el acceso a una base de datos que se asume incluye una colección `tweet`de tweets
#     - `total`: Número mínimo que debe tomar la clave "nRTin" para que el screen_name se a incluya en la salida
# - *Devuelve*: Una lista Python con los screen_name de los usuarios con tweets tales que `nRTin>=total` (puede haber `screen_name` repetidos porque un mismo usuario tenga más de un tweet con estas características)

# %%
def retuiteados(db, total):
    return list(
        db.tweet.find({"nRTin": {"$gte": total}}, {"_id": False, "screen_name": True})
    )


retuiteados(db, 1000)
# Out:
# [{'screen_name': 'LionelMedia'},
#  {'screen_name': 'realDonaldTrump'},
#  {'screen_name': 'TiffanyATrump'},
#  {'screen_name': 'realDonaldTrump'}]

# %% [markdown]
# **Ejercicio 6**  Escribir una función `mas_replicado_que_citado` que devuelva el número de tweets en los que el número de citas recibidas (`nquotein`) es menor que el número de réplicas recibidas (`nreplyin`),
#
# - *Nombre*: `mas_replicado_que_citado`
# - *Parámetros de entrada*:
#     - `db`: el acceso a una base de datos que se asume incluye una colección `tweet`de tweets
# - *Devuelve*: Una lista Python con los screen_name de los usuarios con tweets tales que `nRTin>=total` (puede haber `screen_name` repetidos porque un mismo usuario tenga más de un tweet con estas características)
# - *Obs*: Para comparar dos claves se debe usar el operador [$expr](https://docs.mongodb.com/manual/reference/operator/query/expr/). Observar en la ayuda que al formar parte de una expresión a las se les añade el operador `$` al principio

# %%
def mas_replicado_que_citado(db):
    return db.tweet.count_documents({"$expr": {"$lt": ["$nquotein", "nreplyin"]}})


mas_replicado_que_citado(db)
# Out:
# 3022

# %% [markdown]
# **Ejercicio 7** Queremos generalizar el ejercicio 2 escribiendo una función `num_menciones_todos`
# para conocer el número de tweets que nombran (examinar `user_mentions`) en el mismo tweet a un grupo de usuarios
# dado su `screen_name`
# - *Nombre*: `num_menciones_todos`
# - *Parámetros de entrada*:
#     - `db`: el acceso a una base de datos que se asume incluye una colección `tweet`de tweets
#     - `usuarios`: lista con screen_name de algunos usuarios
#
# - *Devuelve*: número de tweets que mencionan a todos los usuarios.
#
# Pista: buscar entre los operadores para arrays de MongoDB

# %%
# solución
def num_menciones_todos(db, usuarios):
    return db.tweet.count_documents({"user_mentions.screen_name": {"$all": usuarios}})


### para probar el código
print(
    num_menciones_todos(db, ["JoeBiden", "realDonaldTrump"]),
    "menciones a JoeBiden y a realDonalTrump en el mismo tweet",
)
print(
    num_menciones_todos(db, ["JoeBiden", "realDonaldTrump", "CNN"]),
    "menciones a JoeBiden, realDonaldTrump y a la CNN en el mismo tweet",
)
# Out:
# 53 menciones a JoeBiden y a realDonalTrump en el mismo tweet
# 4 menciones a JoeBiden, realDonaldTrump y a la CNN en el mismo tweet

# %% [markdown]
# **Ejercicio 8** Queremos generalizar `retuiteados` para que no repita el nombre de un usuario (`screen_name`) aunque tengan más de un tweet con la cantidad indicada de retweets (clave `nRTin` mayor que un valor).
#
# - *Nombre*: `retuiteados_sinrep`
# - *Parámetros de entrada*:
#     - `db`: el acceso a una base de datos que se asume incluye una colección `tweet`de tweets
#     - `total`: Número mínimo que debe tomar la clave "nRTin" para que el screen_name se a incluya en la salida
# - *Devuelve*: Una estructura  Python con los `screen_name` de los usuarios con tweets tales que `nRTin>=total` (NO puede haber `screen_name` repetidos porque un mismo usuario aunque tenga más de un tweet con estas características)
#
# Ayuda: esta pregunta es más de Python que de MongoDB

# %%
def retuiteados_sinrep(db, total):
    return list(db.tweet.distinct("screen_name", {"nRTin": {"$gte": total}}))


retuiteados_sinrep(db, 1000)
# Out:
# ['LionelMedia', 'TiffanyATrump', 'realDonaldTrump']

# %% [markdown]
# **Ejercicio 9 [2 puntos]** El siguiente código añade ahora datos de usuarios, y muestra alguno de sus documentos

# %%
db = client.practica2
fichero_users = (
    "https://raw.githubusercontent.com/RafaelCaballero/tdm/master/datos/cuser.json"
)
carga_desde_fichero(db, fichero_users, "user")
for doc in list(db.user.find().limit(1000)):
    pprint(doc)
    print("*" * 80)
# Out:
# Colección user: 619 documentos cargados con éxito y 0 errores
# {'_id': '24515539',
#  'created_at': {'date': '2009-03-15T12:17:44Z'},
#  'followers': 197,
#  'friends_count': 979,
#  'geo_enabled': True,
#  'location': 'StJohn usvi,Boston,NYC,Jamaica',
#  'nOriginal': 94,
#  'nRT': 5,
#  'nRTin': 1,
#  'nTotal': 99,
#  'name': 'John SchiffBLM!',
#  'nquotein': 0,
#  'nreplyin': 2,
#  'ntweets': 4892,
#  'screen_name': 'shiffy64',
#  'verified': False}
# ********************************************************************************
# {'_id': '343613163',
#  'created_at': {'date': '2011-07-27T20:44:31Z'},
#  'followers': 42,
#  'friends_count': 197,
#  'geo_enabled': True,
#  'location': None,
#  'nOriginal': 1,
#  'nRT': 0,
#  'nRTin': 0,
#  'nTotal': 1,
#  'name': 'usafa93',
#  'nquotein': 0,
#  'nreplyin': 0,
#  'ntweets': 324,
#  'screen_name': 'usafa1993',
#  'verified': False}
# ********************************************************************************
# {'_id': '250948559',
#  'created_at': {'date': '2011-02-12T03:56:33Z'},
#  'followers': 274,
#  'friends_count': 1323,
#  'geo_enabled': True,
#  'location': 'The Global Village',
#  'nOriginal': 1,
#  'nRT': 0,
#  'nRTin': 0,
#  'nTotal': 1,
#  'name': 'Christoff Smyth',
#  'nquotein': 0,
#  'nreplyin': 0,
#  'ntweets': 2179,
#  'screen_name': 'christoffj',
#  'verified': False}
# ********************************************************************************
# {'_id': '244768935',
#  'created_at': {'date': '2011-01-30T02:59:16Z'},
#  'followers': 206,
#  'friends_count': 287,
#  'geo_enabled': True,
#  'location': 'Veneta, OR',
#  'nOriginal': 18,
#  'nRT': 14,
#  'nRTin': 2,
#  'nTotal': 32,
#  'name': 'Elisabeth Friedman 😷',
#  'nquotein': 0,
#  'nreplyin': 0,
#  'ntweets': 13585,
#  'screen_name': 'YsasWorld',
#  'verified': False}
# ********************************************************************************
# {'_id': '1594536769',
#  'created_at': {'date': '2013-07-14T23:45:24Z'},
#  'followers': 1005,
#  'friends_count': 372,
#  'geo_enabled': True,
#  'location': None,
#  'nOriginal': 1,
#  'nRT': 0,
#  'nRTin': 0,
#  'nTotal': 1,
#  'name': 'Sen James Manning Jr',
#  'nquotein': 0,
#  'nreplyin': 0,
#  'ntweets': 3051,
#  'screen_name': 'manningstl',
#  'verified': False}
# ********************************************************************************
# {'_id': '8443372',
#  'created_at': {'date': '2007-08-26T16:27:58Z'},
#  'followers': 5284,
#  'friends_count': 118,
#  'geo_enabled': True,
#  'location': 'Plant Earth',
#  'nOriginal': 2,
#  'nRT': 0,
#  'nRTin': 0,
#  'nTotal': 2,
#  'name': 'Mark Vogler',
#  'nquotein': 0,
#  'nreplyin': 0,
#  'ntweets': 36130,
#  'screen_name': 'MarkVogler',
#  'verified': False}
# ********************************************************************************
# {'_id': '14308228',
#  'created_at': {'date': '2008-04-05T03:29:16Z'},
#  'followers': 1257,
#  'friends_count': 1142,
#  'geo_enabled': True,
#  'location': 'Portland, OR',
#  'nOriginal': 16,
#  'nRT': 8,
#  'nRTin': 0,
#  'nTotal': 24,
#  'name': 'Jack Cluth',
#  'nquotein': 1,
#  'nreplyin': 1,
#  'ntweets': 74580,
#  'screen_name': 'yuppieskum',
#  'verified': False}
# ********************************************************************************
# {'_id': '93208004',
#  'created_at': {'date': '2009-11-28T15:55:40Z'},
#  'followers': 143,
#  'friends_count': 269,
#  'geo_enabled': True,
#  'location': 'santa Rosa, CA ',
#  'nOriginal': 2,
#  'nRT': 0,
#  'nRTin': 0,
#  'nTotal': 2,
#  'name': 'lajuan hughes',
#  'nquotein': 0,
#  'nreplyin': 0,
#  'ntweets': 7074,
#  'screen_name': 'ljhughes8',
#  'verified': False}
# ********************************************************************************
# {'_id': '38795826',
#  'created_at': {'date': '2009-05-09T04:15:35Z'},
#  'followers': 134,
#  'friends_count': 264,
#  'geo_enabled': True,
#  'location': 'Portland, OR',
#  'nOriginal': 116,
#  'nRT': 11,
#  'nRTin': 4,
#  'nTotal': 127,
#  'name': 'Joshua Hackney',
#  'nquotein': 0,
#  'nreplyin': 7,
#  'ntweets': 4667,
#  'screen_name': 'joshuaxhunter',
#  'verified': False}
# ********************************************************************************
# {'_id': '1145497350',
#  'created_at': {'date': '2013-02-03T15:52:10Z'},
#  'followers': 1396,
#  'friends_count': 240,
#  'geo_enabled': True,
#  'location': 'Portland, OR',
#  'nOriginal': 1,
#  'nRT': 0,
#  'nRTin': 0,
#  'nTotal': 1,
#  'name': 'Vivian Elliott',
#  'nquotein': 0,
#  'nreplyin': 0,
#  'ntweets': 19832,
#  'screen_name': 'VivianIsNotArt',
#  'verified': False}
# ********************************************************************************
# {'_id': '18110050',
#  'created_at': {'date': '2008-12-14T03:02:33Z'},
#  'followers': 556,
#  'friends_count': 1751,
#  'geo_enabled': True,
#  'location': 'Portland, OR',
#  'nOriginal': 2,
#  'nRT': 1,
#  'nRTin': 0,
#  'nTotal': 3,
#  'name': 'Effsgiven',
#  'nquotein': 0,
#  'nreplyin': 0,
#  'ntweets': 39294,
#  'screen_name': 'pjolstead',
#  'verified': False}
# ********************************************************************************
# {'_id': '37513528',
#  'created_at': {'date': '2009-05-03T22:01:15Z'},
#  'followers': 25,
#  'friends_count': 213,
#  'geo_enabled': True,
#  'location': 'Portland, OR',
#  'nOriginal': 3,
#  'nRT': 9,
#  'nRTin': 0,
#  'nTotal': 12,
#  'name': 'CeeDub',
#  'nquotein': 0,
#  'nreplyin': 0,
#  'ntweets': 1417,
#  'screen_name': 'ceedub001',
#  'verified': False}
# ********************************************************************************
# {'_id': '45251704',
#  'created_at': {'date': '2009-06-07T00:55:08Z'},
#  'followers': 458,
#  'friends_count': 1260,
#  'geo_enabled': True,
#  'location': 'San Francisco',
#  'nOriginal': 9,
#  'nRT': 1,
#  'nRTin': 0,
#  'nTotal': 10,
#  'name': 'Krista',
#  'nquotein': 0,
#  'nreplyin': 1,
#  'ntweets': 23999,
#  'screen_name': 'nonsoccermom',
#  'verified': False}
# ********************************************************************************
# {'_id': '28470813',
#  'created_at': {'date': '2009-04-03T01:30:44Z'},
#  'followers': 53,
#  'friends_count': 127,
#  'geo_enabled': True,
#  'location': 'Tacoma, WA',
#  'nOriginal': 1,
#  'nRT': 0,
#  'nRTin': 0,
#  'nTotal': 1,
#  'name': 'Marky',
#  'nquotein': 0,
#  'nreplyin': 0,
#  'ntweets': 3628,
#  'screen_name': 'swirl253',
#  'verified': False}
# ********************************************************************************
# {'_id': '14571523',
#  'created_at': {'date': '2008-04-28T16:37:21Z'},
#  'followers': 124,
#  'friends_count': 325,
#  'geo_enabled': True,
#  'location': 'Half Moon Bay, California',
#  'nOriginal': 2,
#  'nRT': 0,
#  'nRTin': 0,
#  'nTotal': 2,
#  'name': 'Michael Grant',
#  'nquotein': 0,
#  'nreplyin': 0,
#  'ntweets': 1728,
#  'screen_name': 'michaelgrant',
#  'verified': False}
# ********************************************************************************
# {'_id': '85703993',
#  'created_at': {'date': '2009-10-28T00:33:42Z'},
#  'followers': 44,
#  'friends_count': 133,
#  'geo_enabled': True,
#  'location': 'Thermal, Ca',
#  'nOriginal': 1,
#  'nRT': 0,
#  'nRTin': 0,
#  'nTotal': 1,
#  'name': 'Christina Kelso',
#  'nquotein': 0,
#  'nreplyin': 0,
#  'ntweets': 176,
#  'screen_name': 'kelsochristina',
#  'verified': False}
# ********************************************************************************
# {'_id': '20428617',
#  'created_at': {'date': '2009-02-09T11:12:36Z'},
#  'followers': 1049,
#  'friends_count': 2432,
#  'geo_enabled': True,
#  'location': 'San Francisco',
#  'nOriginal': 1,
#  'nRT': 0,
#  'nRTin': 0,
#  'nTotal': 1,
#  'name': 'michael meadows',
#  'nquotein': 0,
#  'nreplyin': 0,
#  'ntweets': 5609,
#  'screen_name': 'MichaelEatsSF',
#  'verified': False}
# ********************************************************************************
# {'_id': '25242954',
#  'created_at': {'date': '2009-03-19T05:13:11Z'},
#  'followers': 996,
#  'friends_count': 4368,
#  'geo_enabled': True,
#  'location': 'San Francisco, CA',
#  'nOriginal': 1,
#  'nRT': 0,
#  'nRTin': 0,
#  'nTotal': 1,
#  'name': 'Rob McKelvey ®',
#  'nquotein': 0,
#  'nreplyin': 0,
#  'ntweets': 23439,
#  'screen_name': 'RobMcKelvey',
#  'verified': False}
# ********************************************************************************
# {'_id': '273686647',
#  'created_at': {'date': '2011-03-28T23:56:57Z'},
#  'followers': 44,
#  'friends_count': 44,
#  'geo_enabled': True,
#  'location': None,
#  'nOriginal': 8,
#  'nRT': 0,
#  'nRTin': 3,
#  'nTotal': 8,
#  'name': 'Kevin Broccoli',
#  'nquotein': 0,
#  'nreplyin': 6,
#  'ntweets': 3572,
#  'screen_name': 'kevin_broccoli',
#  'verified': False}
# ********************************************************************************
# {'_id': '66906717',
#  'created_at': {'date': '2009-08-19T04:13:03Z'},
#  'followers': 785,
#  'friends_count': 645,
#  'geo_enabled': True,
#  'location': 'San Francisco',
#  'nOriginal': 1,
#  'nRT': 0,
#  'nRTin': 0,
#  'nTotal': 1,
#  'name': 'The Pressroom & Mercantile at Box SF',
#  'nquotein': 1,
#  'nreplyin': 0,
#  'ntweets': 6911,
#  'screen_name': 'TheBoxSF',
#  'verified': False}
# ********************************************************************************
# {'_id': '55019353',
#  'created_at': {'date': '2009-07-08T20:32:58Z'},
#  'followers': 1774,
#  'friends_count': 1898,
#  'geo_enabled': True,
#  'location': 'Seattle, WA',
#  'nOriginal': 8,
#  'nRT': 0,
#  'nRTin': 1,
#  'nTotal': 8,
#  'name': '⭐️FOTY13⭐️',
#  'nquotein': 0,
#  'nreplyin': 0,
#  'ntweets': 122651,
#  'screen_name': 'SSFCFOTY13',
#  'verified': False}
# ********************************************************************************
# {'_id': '579397497',
#  'created_at': {'date': '2012-05-13T21:54:34Z'},
#  'followers': 1410,
#  'friends_count': 341,
#  'geo_enabled': True,
#  'location': 'Seattle, WA',
#  'nOriginal': 1,
#  'nRT': 0,
#  'nRTin': 0,
#  'nTotal': 1,
#  'name': 'debspottery',
#  'nquotein': 0,
#  'nreplyin': 0,
#  'ntweets': 2293,
#  'screen_name': 'DebsPottery',
#  'verified': False}
# ********************************************************************************
# {'_id': '529523360',
#  'created_at': {'date': '2012-03-19T16:45:25Z'},
#  'followers': 3461,
#  'friends_count': 2869,
#  'geo_enabled': True,
#  'location': 'Seattle, WA',
#  'nOriginal': 1,
#  'nRT': 0,
#  'nRTin': 1,
#  'nTotal': 1,
#  'name': 'Rep. Noel Frame',
#  'nquotein': 0,
#  'nreplyin': 0,
#  'ntweets': 1933,
#  'screen_name': 'NoelFrame',
#  'verified': False}
# ********************************************************************************
# {'_id': '50925602',
#  'created_at': {'date': '2009-06-26T04:44:19Z'},
#  'followers': 4539,
#  'friends_count': 3167,
#  'geo_enabled': True,
#  'location': 'Albuquerque, NM',
#  'nOriginal': 36,
#  'nRT': 1,
#  'nRTin': 6,
#  'nTotal': 37,
#  'name': 'Hakim Bellamy',
#  'nquotein': 13,
#  'nreplyin': 3,
#  'ntweets': 37907,
#  'screen_name': 'HakimBe',
#  'verified': False}
# ********************************************************************************
# {'_id': '109772253',
#  'created_at': {'date': '2010-01-30T05:56:47Z'},
#  'followers': 120,
#  'friends_count': 132,
#  'geo_enabled': True,
#  'location': 'Seattle, WA',
#  'nOriginal': 2,
#  'nRT': 0,
#  'nRTin': 0,
#  'nTotal': 2,
#  'name': 'Ashy Mcgee',
#  'nquotein': 0,
#  'nreplyin': 0,
#  'ntweets': 2073,
#  'screen_name': 'ashymcgee',
#  'verified': False}
# ********************************************************************************
# {'_id': '51957830',
#  'created_at': {'date': '2009-06-29T04:25:57Z'},
#  'followers': 1129,
#  'friends_count': 421,
#  'geo_enabled': True,
#  'location': 'PNW ',
#  'nOriginal': 34,
#  'nRT': 0,
#  'nRTin': 0,
#  'nTotal': 34,
#  'name': 'deepthought',
#  'nquotein': 0,
#  'nreplyin': 0,
#  'ntweets': 57388,
#  'screen_name': 'suchweresomeofu',
#  'verified': False}
# ********************************************************************************
# {'_id': '14041342',
#  'created_at': {'date': '2008-02-27T01:35:49Z'},
#  'followers': 349,
#  'friends_count': 1005,
#  'geo_enabled': True,
#  'location': 'iPhone: 47.697560,-122.290630',
#  'nOriginal': 5,
#  'nRT': 4,
#  'nRTin': 0,
#  'nTotal': 9,
#  'name': 'Christopher Shaw',
#  'nquotein': 0,
#  'nreplyin': 0,
#  'ntweets': 3620,
#  'screen_name': 'zeroego',
#  'verified': False}
# ********************************************************************************
# {'_id': '2595384901',
#  'created_at': {'date': '2014-06-29T21:57:46Z'},
#  'followers': 92,
#  'friends_count': 221,
#  'geo_enabled': True,
#  'location': 'San Francisco CA',
#  'nOriginal': 8,
#  'nRT': 0,
#  'nRTin': 1,
#  'nTotal': 8,
#  'name': 'Pip Trousdale',
#  'nquotein': 0,
#  'nreplyin': 1,
#  'ntweets': 2143,
#  'screen_name': 'PipTrousdale',
#  'verified': False}
# ********************************************************************************
# {'_id': '123058808',
#  'created_at': {'date': '2010-03-14T21:19:19Z'},
#  'followers': 69,
#  'friends_count': 193,
#  'geo_enabled': True,
#  'location': 'Oakland, CA',
#  'nOriginal': 1,
#  'nRT': 0,
#  'nRTin': 0,
#  'nTotal': 1,
#  'name': 'Joseph MaKing',
#  'nquotein': 0,
#  'nreplyin': 0,
#  'ntweets': 7893,
#  'screen_name': 'Nyjokingecho',
#  'verified': False}
# ********************************************************************************
# {'_id': '15921136',
#  'created_at': {'date': '2008-08-20T18:36:25Z'},
#  'followers': 1011,
#  'friends_count': 2212,
#  'geo_enabled': True,
#  'location': 'Mare Island, CA',
#  'nOriginal': 3,
#  'nRT': 2,
#  'nRTin': 0,
#  'nTotal': 5,
#  'name': 'Paul Wilke',
#  'nquotein': 0,
#  'nreplyin': 0,
#  'ntweets': 9026,
#  'screen_name': 'pwilke',
#  'verified': False}
# ********************************************************************************
# {'_id': '19625720',
#  'created_at': {'date': '2009-01-27T23:57:42Z'},
#  'followers': 444,
#  'friends_count': 445,
#  'geo_enabled': True,
#  'location': 'Auburn, CA USA',
#  'nOriginal': 3,
#  'nRT': 2,
#  'nRTin': 0,
#  'nTotal': 5,
#  'name': 'Aaron D.',
#  'nquotein': 0,
#  'nreplyin': 0,
#  'ntweets': 6159,
#  'screen_name': 'InsideEvil',
#  'verified': False}
# ********************************************************************************
# {'_id': '36038257',
#  'created_at': {'date': '2009-04-28T10:58:30Z'},
#  'followers': 2947,
#  'friends_count': 1792,
#  'geo_enabled': True,
#  'location': 'Sumner, Washington, U.S.A',
#  'nOriginal': 1,
#  'nRT': 3,
#  'nRTin': 0,
#  'nTotal': 4,
#  'name': 'James Christiansen',
#  'nquotein': 0,
#  'nreplyin': 0,
#  'ntweets': 100248,
#  'screen_name': 'SLAYERSWINE',
#  'verified': False}
# ********************************************************************************
# {'_id': '125331676',
#  'created_at': {'date': '2010-03-22T13:29:29Z'},
#  'followers': 264,
#  'friends_count': 303,
#  'geo_enabled': True,
#  'location': 'Palo Alto, CA',
#  'nOriginal': 2,
#  'nRT': 0,
#  'nRTin': 0,
#  'nTotal': 2,
#  'name': 'Ric MarshallNicholls',
#  'nquotein': 0,
#  'nreplyin': 0,
#  'ntweets': 7786,
#  'screen_name': 'Ric_MN',
#  'verified': False}
# ********************************************************************************
# {'_id': '1253694944507686912',
#  'created_at': {'date': '2020-04-24T14:39:22Z'},
#  'followers': 11,
#  'friends_count': 54,
#  'geo_enabled': True,
#  'location': 'Phuket Province, Thailand',
#  'nOriginal': 9,
#  'nRT': 0,
#  'nRTin': 0,
#  'nTotal': 9,
#  'name': 'Kristian Petersen',
#  'nquotein': 2,
#  'nreplyin': 0,
#  'ntweets': 364,
#  'screen_name': 'Kristia73924120',
#  'verified': False}
# ********************************************************************************
# {'_id': '36726043',
#  'created_at': {'date': '2009-04-30T17:56:17Z'},
#  'followers': 3433,
#  'friends_count': 4995,
#  'geo_enabled': True,
#  'location': 'Silicon Valley born and raised',
#  'nOriginal': 2,
#  'nRT': 0,
#  'nRTin': 0,
#  'nTotal': 2,
#  'name': 'Erin Jerri Pangilinan #Masks4All',
#  'nquotein': 0,
#  'nreplyin': 0,
#  'ntweets': 17757,
#  'screen_name': 'erinjerri',
#  'verified': False}
# ********************************************************************************
# {'_id': '18204820',
#  'created_at': {'date': '2008-12-18T00:54:32Z'},
#  'followers': 382,
#  'friends_count': 543,
#  'geo_enabled': True,
#  'location': 'Norcal',
#  'nOriginal': 1,
#  'nRT': 0,
#  'nRTin': 0,
#  'nTotal': 1,
#  'name': 'Angela Restani',
#  'nquotein': 0,
#  'nreplyin': 0,
#  'ntweets': 749,
#  'screen_name': 'angrestani',
#  'verified': False}
# ********************************************************************************
# {'_id': '33091531',
#  'created_at': {'date': '2009-04-19T02:00:30Z'},
#  'followers': 61,
#  'friends_count': 158,
#  'geo_enabled': True,
#  'location': 'San Jose, CA',
#  'nOriginal': 2,
#  'nRT': 0,
#  'nRTin': 0,
#  'nTotal': 2,
#  'name': 'The Funko Chef',
#  'nquotein': 0,
#  'nreplyin': 0,
#  'ntweets': 1603,
#  'screen_name': 'easchef',
#  'verified': False}
# ********************************************************************************
# {'_id': '2347105118',
#  'created_at': {'date': '2014-02-16T16:28:56Z'},
#  'followers': 301,
#  'friends_count': 575,
#  'geo_enabled': True,
#  'location': 'The World',
#  'nOriginal': 6,
#  'nRT': 0,
#  'nRTin': 0,
#  'nTotal': 6,
#  'name': 'Raymond Del Barrio',
#  'nquotein': 1,
#  'nreplyin': 0,
#  'ntweets': 5324,
#  'screen_name': 'RamonDelBarrio',
#  'verified': False}
# ********************************************************************************
# {'_id': '23785303',
#  'created_at': {'date': '2009-03-11T16:22:11Z'},
#  'followers': 117,
#  'friends_count': 728,
#  'geo_enabled': True,
#  'location': 'United States of America',
#  'nOriginal': 5,
#  'nRT': 1,
#  'nRTin': 0,
#  'nTotal': 6,
#  'name': 'Mia',
#  'nquotein': 0,
#  'nreplyin': 0,
#  'ntweets': 17820,
#  'screen_name': 'smilemymia',
#  'verified': False}
# ********************************************************************************
# {'_id': '218435721',
#  'created_at': {'date': '2010-11-22T10:26:50Z'},
#  'followers': 950,
#  'friends_count': 994,
#  'geo_enabled': True,
#  'location': 'Sacramento, California',
#  'nOriginal': 1,
#  'nRT': 0,
#  'nRTin': 0,
#  'nTotal': 1,
#  'name': 'Dallin Bryce',
#  'nquotein': 0,
#  'nreplyin': 0,
#  'ntweets': 11748,
#  'screen_name': 'dallinbryce',
#  'verified': False}
# ********************************************************************************
# {'_id': '427101334',
#  'created_at': {'date': '2011-12-03T03:32:56Z'},
#  'followers': 2894,
#  'friends_count': 3077,
#  'geo_enabled': True,
#  'location': 'Sacramento, CA',
#  'nOriginal': 1,
#  'nRT': 2,
#  'nRTin': 2,
#  'nTotal': 3,
#  'name': 'Seth Bramble',
#  'nquotein': 0,
#  'nreplyin': 1,
#  'ntweets': 18478,
#  'screen_name': 'CATeachersGR',
#  'verified': False}
# ********************************************************************************
# {'_id': '200702346',
#  'created_at': {'date': '2010-10-10T00:53:00Z'},
#  'followers': 409,
#  'friends_count': 1407,
#  'geo_enabled': True,
#  'location': 'Las Vegas, NV',
#  'nOriginal': 1,
#  'nRT': 0,
#  'nRTin': 0,
#  'nTotal': 1,
#  'name': 'Julie G Photography',
#  'nquotein': 0,
#  'nreplyin': 0,
#  'ntweets': 2277,
#  'screen_name': 'juliegibbs25',
#  'verified': False}
# ********************************************************************************
# {'_id': '15014042',
#  'created_at': {'date': '2008-06-05T03:55:36Z'},
#  'followers': 1023,
#  'friends_count': 944,
#  'geo_enabled': True,
#  'location': 'Fremont, CA',
#  'nOriginal': 1,
#  'nRT': 6,
#  'nRTin': 0,
#  'nTotal': 7,
#  'name': 'Kevin Crossman',
#  'nquotein': 0,
#  'nreplyin': 0,
#  'ntweets': 43492,
#  'screen_name': 'KevinCrossman',
#  'verified': False}
# ********************************************************************************
# {'_id': '826549394606546946',
#  'created_at': {'date': '2017-01-31T21:55:07Z'},
#  'followers': 1417,
#  'friends_count': 79,
#  'geo_enabled': True,
#  'location': 'Oklahoma City, Oklahoma',
#  'nOriginal': 337,
#  'nRT': 0,
#  'nRTin': 14,
#  'nTotal': 337,
#  'name': 'Lumberjack Hill',
#  'nquotein': 2,
#  'nreplyin': 3,
#  'ntweets': 3039,
#  'screen_name': 'LumberjackHill',
#  'verified': False}
# ********************************************************************************
# {'_id': '99230421',
#  'created_at': {'date': '2009-12-25T06:10:07Z'},
#  'followers': 61,
#  'friends_count': 316,
#  'geo_enabled': True,
#  'location': 'Fresno, CA',
#  'nOriginal': 1,
#  'nRT': 0,
#  'nRTin': 0,
#  'nTotal': 1,
#  'name': 'Martin Corona',
#  'nquotein': 0,
#  'nreplyin': 0,
#  'ntweets': 2166,
#  'screen_name': 'marttymar',
#  'verified': False}
# ********************************************************************************
# {'_id': '161605938',
#  'created_at': {'date': '2010-07-01T08:01:32Z'},
#  'followers': 3112,
#  'friends_count': 4999,
#  'geo_enabled': True,
#  'location': 'Clovis, CA',
#  'nOriginal': 7,
#  'nRT': 41,
#  'nRTin': 0,
#  'nTotal': 48,
#  'name': 'Kenneth Paar',
#  'nquotein': 0,
#  'nreplyin': 0,
#  'ntweets': 128487,
#  'screen_name': 'MyParExcellence',
#  'verified': False}
# ********************************************************************************
# {'_id': '611439915',
#  'created_at': {'date': '2012-06-18T03:47:59Z'},
#  'followers': 1490,
#  'friends_count': 958,
#  'geo_enabled': True,
#  'location': 'Scottsdale, Arizona',
#  'nOriginal': 189,
#  'nRT': 58,
#  'nRTin': 54,
#  'nTotal': 247,
#  'name': 'Christy',
#  'nquotein': 12,
#  'nreplyin': 392,
#  'ntweets': 11768,
#  'screen_name': 'BriskeyBaby',
#  'verified': False}
# ********************************************************************************
# {'_id': '1687536504',
#  'created_at': {'date': '2013-08-21T06:15:55Z'},
#  'followers': 888,
#  'friends_count': 3727,
#  'geo_enabled': True,
#  'location': 'Los Angeles, CA',
#  'nOriginal': 22,
#  'nRT': 6,
#  'nRTin': 2,
#  'nTotal': 28,
#  'name': 'Worldwide™',
#  'nquotein': 0,
#  'nreplyin': 4,
#  'ntweets': 25292,
#  'screen_name': 'bmxministry',
#  'verified': False}
# ********************************************************************************
# {'_id': '37534994',
#  'created_at': {'date': '2009-05-03T23:42:14Z'},
#  'followers': 389667,
#  'friends_count': 6,
#  'geo_enabled': True,
#  'location': 'Los Angeles, CA',
#  'nOriginal': 4,
#  'nRT': 0,
#  'nRTin': 0,
#  'nTotal': 4,
#  'name': 'LA QuakeBot',
#  'nquotein': 5,
#  'nreplyin': 0,
#  'ntweets': 21679,
#  'screen_name': 'earthquakesLA',
#  'verified': False}
# ********************************************************************************
# {'_id': '16435655',
#  'created_at': {'date': '2008-09-24T15:17:36Z'},
#  'followers': 327,
#  'friends_count': 1501,
#  'geo_enabled': True,
#  'location': 'San Francisco, CA',
#  'nOriginal': 1,
#  'nRT': 0,
#  'nRTin': 0,
#  'nTotal': 1,
#  'name': 'Larry Bisagni',
#  'nquotein': 0,
#  'nreplyin': 0,
#  'ntweets': 2158,
#  'screen_name': 'LBizzy',
#  'verified': False}
# ********************************************************************************
# {'_id': '1067888378',
#  'created_at': {'date': '2013-01-07T09:34:32Z'},
#  'followers': 1011,
#  'friends_count': 632,
#  'geo_enabled': True,
#  'location': 'Los Angeles',
#  'nOriginal': 1,
#  'nRT': 0,
#  'nRTin': 1,
#  'nTotal': 1,
#  'name': 'Vern Laird',
#  'nquotein': 0,
#  'nreplyin': 0,
#  'ntweets': 7093,
#  'screen_name': 'vernlaird',
#  'verified': False}
# ********************************************************************************
# {'_id': '281793679',
#  'created_at': {'date': '2011-04-14T00:11:35Z'},
#  'followers': 1428,
#  'friends_count': 315,
#  'geo_enabled': True,
#  'location': 'Los Angeles, Ca',
#  'nOriginal': 15,
#  'nRT': 0,
#  'nRTin': 1,
#  'nTotal': 15,
#  'name': 'Jonathon Brannon',
#  'nquotein': 0,
#  'nreplyin': 1,
#  'ntweets': 5552,
#  'screen_name': 'BrannonMusic',
#  'verified': False}
# ********************************************************************************
# {'_id': '305922144',
#  'created_at': {'date': '2011-05-27T00:28:35Z'},
#  'followers': 37046,
#  'friends_count': 388,
#  'geo_enabled': True,
#  'location': '└A',
#  'nOriginal': 1,
#  'nRT': 0,
#  'nRTin': 0,
#  'nTotal': 1,
#  'name': 'Ricky Jaime',
#  'nquotein': 0,
#  'nreplyin': 0,
#  'ntweets': 9097,
#  'screen_name': 'D8Ricky',
#  'verified': True}
# ********************************************************************************
# {'_id': '27721304',
#  'created_at': {'date': '2009-03-30T20:30:42Z'},
#  'followers': 10158,
#  'friends_count': 738,
#  'geo_enabled': True,
#  'location': 'Temecula, CA',
#  'nOriginal': 1,
#  'nRT': 0,
#  'nRTin': 0,
#  'nTotal': 1,
#  'name': 'Jeremy Jackson',
#  'nquotein': 1,
#  'nreplyin': 0,
#  'ntweets': 2225,
#  'screen_name': '_JeremyJackson_',
#  'verified': True}
# ********************************************************************************
# {'_id': '729562032580632577',
#  'created_at': {'date': '2016-05-09T06:41:58Z'},
#  'followers': 763,
#  'friends_count': 65,
#  'geo_enabled': True,
#  'location': 'West Hollywood, CA',
#  'nOriginal': 1,
#  'nRT': 0,
#  'nRTin': 0,
#  'nTotal': 1,
#  'name': 'The Chapel 🏳️\u200d🌈',
#  'nquotein': 0,
#  'nreplyin': 0,
#  'ntweets': 4237,
#  'screen_name': 'thechapelweho',
#  'verified': False}
# ********************************************************************************
# {'_id': '119972195',
#  'created_at': {'date': '2010-03-05T03:08:57Z'},
#  'followers': 1658,
#  'friends_count': 1081,
#  'geo_enabled': True,
#  'location': 'Hollywood',
#  'nOriginal': 3,
#  'nRT': 0,
#  'nRTin': 0,
#  'nTotal': 3,
#  'name': 'Rob DaRocha',
#  'nquotein': 0,
#  'nreplyin': 0,
#  'ntweets': 12524,
#  'screen_name': 'robdarocha',
#  'verified': False}
# ********************************************************************************
# {'_id': '2931649466',
#  'created_at': {'date': '2014-12-15T23:34:01Z'},
#  'followers': 2157,
#  'friends_count': 4914,
#  'geo_enabled': True,
#  'location': 'Hollywood, CA',
#  'nOriginal': 9,
#  'nRT': 0,
#  'nRTin': 0,
#  'nTotal': 9,
#  'name': 'Peter Santana',
#  'nquotein': 0,
#  'nreplyin': 0,
#  'ntweets': 6418,
#  'screen_name': 'ElPeterSantana',
#  'verified': False}
# ********************************************************************************
# {'_id': '97093665',
#  'created_at': {'date': '2009-12-16T00:15:16Z'},
#  'followers': 141,
#  'friends_count': 216,
#  'geo_enabled': True,
#  'location': 'Hollywood ⭐',
#  'nOriginal': 1,
#  'nRT': 1,
#  'nRTin': 1,
#  'nTotal': 2,
#  'name': 'ⓢⓟⓞⓞⓚⓨ🎃ⓑⓔⓝⓝⓨ',
#  'nquotein': 0,
#  'nreplyin': 0,
#  'ntweets': 2918,
#  'screen_name': 'iSeeCyrus',
#  'verified': False}
# ********************************************************************************
# {'_id': '26891704',
#  'created_at': {'date': '2009-03-26T23:49:15Z'},
#  'followers': 2874,
#  'friends_count': 398,
#  'geo_enabled': True,
#  'location': 'Manhattan Beach, CA',
#  'nOriginal': 5,
#  'nRT': 0,
#  'nRTin': 0,
#  'nTotal': 5,
#  'name': 'Brian Rubenstein',
#  'nquotein': 0,
#  'nreplyin': 3,
#  'ntweets': 5148,
#  'screen_name': 'irwinhandleman',
#  'verified': False}
# ********************************************************************************
# {'_id': '49244936',
#  'created_at': {'date': '2009-06-21T05:39:59Z'},
#  'followers': 694,
#  'friends_count': 1336,
#  'geo_enabled': True,
#  'location': 'Los Angeles, CA',
#  'nOriginal': 1,
#  'nRT': 0,
#  'nRTin': 0,
#  'nTotal': 1,
#  'name': 'Russell Wolff',
#  'nquotein': 0,
#  'nreplyin': 0,
#  'ntweets': 5590,
#  'screen_name': 'RussellWolff',
#  'verified': False}
# ********************************************************************************
# {'_id': '16258178',
#  'created_at': {'date': '2008-09-12T16:01:21Z'},
#  'followers': 131,
#  'friends_count': 92,
#  'geo_enabled': True,
#  'location': None,
#  'nOriginal': 2,
#  'nRT': 0,
#  'nRTin': 0,
#  'nTotal': 2,
#  'name': 'Kimmy Jo',
#  'nquotein': 0,
#  'nreplyin': 0,
#  'ntweets': 760,
#  'screen_name': 'KJREDHEAD',
#  'verified': False}
# ********************************************************************************
# {'_id': '15918356',
#  'created_at': {'date': '2008-08-20T14:57:50Z'},
#  'followers': 873,
#  'friends_count': 928,
#  'geo_enabled': True,
#  'location': 'Inglewood, CA',
#  'nOriginal': 1,
#  'nRT': 0,
#  'nRTin': 0,
#  'nTotal': 1,
#  'name': '𝕴 𝕬 𝕹    𝕻 𝕬 𝕷 𝕸 𝕰 𝕽',
#  'nquotein': 0,
#  'nreplyin': 0,
#  'ntweets': 16448,
#  'screen_name': 'etothemajor',
#  'verified': False}
# ********************************************************************************
# {'_id': '213894931',
#  'created_at': {'date': '2010-11-10T01:41:53Z'},
#  'followers': 1440,
#  'friends_count': 910,
#  'geo_enabled': True,
#  'location': 'Hollywood, Los Angeles',
#  'nOriginal': 11,
#  'nRT': 0,
#  'nRTin': 0,
#  'nTotal': 11,
#  'name': 'American Prayer Warrior',
#  'nquotein': 1,
#  'nreplyin': 0,
#  'ntweets': 30409,
#  'screen_name': 'ShinelovesJesus',
#  'verified': False}
# ********************************************************************************
# {'_id': '55697858',
#  'created_at': {'date': '2009-07-10T23:33:48Z'},
#  'followers': 414,
#  'friends_count': 512,
#  'geo_enabled': True,
#  'location': 'Los Angeles, CA',
#  'nOriginal': 2,
#  'nRT': 0,
#  'nRTin': 0,
#  'nTotal': 2,
#  'name': 'Raj Raghavan',
#  'nquotein': 0,
#  'nreplyin': 0,
#  'ntweets': 1573,
#  'screen_name': 'rajvr42',
#  'verified': False}
# ********************************************************************************
# {'_id': '43733588',
#  'created_at': {'date': '2009-05-31T18:51:28Z'},
#  'followers': 595,
#  'friends_count': 1789,
#  'geo_enabled': True,
#  'location': 'Earth',
#  'nOriginal': 6,
#  'nRT': 0,
#  'nRTin': 1,
#  'nTotal': 6,
#  'name': 'PurpleHaayz',
#  'nquotein': 0,
#  'nreplyin': 0,
#  'ntweets': 4389,
#  'screen_name': 'PurpleHaayz',
#  'verified': False}
# ********************************************************************************
# {'_id': '3016270838',
#  'created_at': {'date': '2015-02-10T09:01:06Z'},
#  'followers': 36,
#  'friends_count': 69,
#  'geo_enabled': True,
#  'location': 'Los Angeles',
#  'nOriginal': 1,
#  'nRT': 0,
#  'nRTin': 0,
#  'nTotal': 1,
#  'name': 'Diane Ortega',
#  'nquotein': 0,
#  'nreplyin': 0,
#  'ntweets': 83,
#  'screen_name': 'Dianamite2112',
#  'verified': False}
# ********************************************************************************
# {'_id': '574668309',
#  'created_at': {'date': '2012-05-08T16:03:40Z'},
#  'followers': 485,
#  'friends_count': 28,
#  'geo_enabled': True,
#  'location': 'Burbank CA 91504',
#  'nOriginal': 20,
#  'nRT': 0,
#  'nRTin': 52,
#  'nTotal': 20,
#  'name': 'Jesse Clark',
#  'nquotein': 12,
#  'nreplyin': 7,
#  'ntweets': 1985,
#  'screen_name': 'Universal91504',
#  'verified': False}
# ********************************************************************************
# {'_id': '315612427',
#  'created_at': {'date': '2011-06-12T04:52:35Z'},
#  'followers': 80,
#  'friends_count': 36,
#  'geo_enabled': True,
#  'location': 'USA',
#  'nOriginal': 1,
#  'nRT': 0,
#  'nRTin': 0,
#  'nTotal': 1,
#  'name': 'DBRP',
#  'nquotein': 0,
#  'nreplyin': 0,
#  'ntweets': 2296,
#  'screen_name': 'DBL3',
#  'verified': False}
# ********************************************************************************
# {'_id': '824310413030408192',
#  'created_at': {'date': '2017-01-25T17:38:12Z'},
#  'followers': 65,
#  'friends_count': 173,
#  'geo_enabled': True,
#  'location': 'West Hollywood, CA',
#  'nOriginal': 7,
#  'nRT': 0,
#  'nRTin': 0,
#  'nTotal': 7,
#  'name': 'Jose',
#  'nquotein': 0,
#  'nreplyin': 0,
#  'ntweets': 77,
#  'screen_name': 'lcplpulido',
#  'verified': False}
# ********************************************************************************
# {'_id': '891002285722972160',
#  'created_at': {'date': '2017-07-28T18:27:53Z'},
#  'followers': 387,
#  'friends_count': 1505,
#  'geo_enabled': True,
#  'location': 'Los Angeles, CA',
#  'nOriginal': 11,
#  'nRT': 5,
#  'nRTin': 3,
#  'nTotal': 16,
#  'name': 'AljustAl',
#  'nquotein': 1,
#  'nreplyin': 4,
#  'ntweets': 9032,
#  'screen_name': 'AlbertHolguin51',
#  'verified': False}
# ********************************************************************************
# {'_id': '291726781',
#  'created_at': {'date': '2011-05-02T14:31:44Z'},
#  'followers': 1488,
#  'friends_count': 2068,
#  'geo_enabled': True,
#  'location': 'New Jersey/ new york',
#  'nOriginal': 2,
#  'nRT': 0,
#  'nRTin': 0,
#  'nTotal': 2,
#  'name': 'Rosh👑',
#  'nquotein': 0,
#  'nreplyin': 0,
#  'ntweets': 31967,
#  'screen_name': 'badmatos239',
#  'verified': False}
# ********************************************************************************
# {'_id': '485604840',
#  'created_at': {'date': '2012-02-07T11:31:28Z'},
#  'followers': 367,
#  'friends_count': 1694,
#  'geo_enabled': True,
#  'location': 'Los Angeles, CA',
#  'nOriginal': 1,
#  'nRT': 1,
#  'nRTin': 0,
#  'nTotal': 2,
#  'name': 'White Noize',
#  'nquotein': 0,
#  'nreplyin': 0,
#  'ntweets': 2182,
#  'screen_name': 'RealWhiteNoize',
#  'verified': False}
# ********************************************************************************
# {'_id': '54141172',
#  'created_at': {'date': '2009-07-06T06:52:32Z'},
#  'followers': 47,
#  'friends_count': 439,
#  'geo_enabled': True,
#  'location': 'Los Angeles, CA',
#  'nOriginal': 9,
#  'nRT': 208,
#  'nRTin': 0,
#  'nTotal': 217,
#  'name': 'Juan Gonzalez',
#  'nquotein': 0,
#  'nreplyin': 0,
#  'ntweets': 7195,
#  'screen_name': 'Healthycityboy',
#  'verified': False}
# ********************************************************************************
# {'_id': '4900065260',
#  'created_at': {'date': '2016-02-13T03:23:12Z'},
#  'followers': 1957,
#  'friends_count': 2209,
#  'geo_enabled': True,
#  'location': 'Los Angeles, CA',
#  'nOriginal': 27,
#  'nRT': 9,
#  'nRTin': 3,
#  'nTotal': 36,
#  'name': 'Kat Dekari',
#  'nquotein': 1,
#  'nreplyin': 0,
#  'ntweets': 9088,
#  'screen_name': 'katdekari',
#  'verified': False}
# ********************************************************************************
# {'_id': '77386997',
#  'created_at': {'date': '2009-09-26T03:34:41Z'},
#  'followers': 1912,
#  'friends_count': 4931,
#  'geo_enabled': True,
#  'location': 'West Hollywood, CA',
#  'nOriginal': 4,
#  'nRT': 15,
#  'nRTin': 0,
#  'nTotal': 19,
#  'name': 'Wake Up Morning Would',
#  'nquotein': 0,
#  'nreplyin': 0,
#  'ntweets': 42649,
#  'screen_name': 'TheCurtCollins',
#  'verified': False}
# ********************************************************************************
# {'_id': '2618475764',
#  'created_at': {'date': '2014-07-11T20:19:39Z'},
#  'followers': 73,
#  'friends_count': 317,
#  'geo_enabled': True,
#  'location': 'Venice, Ca.',
#  'nOriginal': 1,
#  'nRT': 0,
#  'nRTin': 0,
#  'nTotal': 1,
#  'name': 'Daniel Rodriguez',
#  'nquotein': 0,
#  'nreplyin': 0,
#  'ntweets': 3094,
#  'screen_name': 'bigd_310',
#  'verified': False}
# ********************************************************************************
# {'_id': '2583257775',
#  'created_at': {'date': '2014-06-04T22:44:08Z'},
#  'followers': 185,
#  'friends_count': 504,
#  'geo_enabled': True,
#  'location': 'Los Angeles, CA',
#  'nOriginal': 6,
#  'nRT': 1,
#  'nRTin': 0,
#  'nTotal': 7,
#  'name': 'briankealty',
#  'nquotein': 0,
#  'nreplyin': 0,
#  'ntweets': 1786,
#  'screen_name': 'briankealty',
#  'verified': False}
# ********************************************************************************
# {'_id': '558081927',
#  'created_at': {'date': '2012-04-19T19:46:10Z'},
#  'followers': 1314,
#  'friends_count': 622,
#  'geo_enabled': True,
#  'location': 'Los Angeles via Brazil',
#  'nOriginal': 1,
#  'nRT': 0,
#  'nRTin': 0,
#  'nTotal': 1,
#  'name': 'FÁBIO BORGES',
#  'nquotein': 1,
#  'nreplyin': 0,
#  'ntweets': 5057,
#  'screen_name': 'FabioBorgesTV',
#  'verified': True}
# ********************************************************************************
# {'_id': '1643269226',
#  'created_at': {'date': '2013-08-03T17:16:48Z'},
#  'followers': 21,
#  'friends_count': 109,
#  'geo_enabled': True,
#  'location': 'Los Angeles, CA',
#  'nOriginal': 3,
#  'nRT': 0,
#  'nRTin': 0,
#  'nTotal': 3,
#  'name': 'Zak spparow',
#  'nquotein': 0,
#  'nreplyin': 0,
#  'ntweets': 968,
#  'screen_name': 'Zakspparow69',
#  'verified': False}
# ********************************************************************************
# {'_id': '511119478',
#  'created_at': {'date': '2012-03-02T00:47:34Z'},
#  'followers': 1223,
#  'friends_count': 62,
#  'geo_enabled': True,
#  'location': 'Hollywood, California U.S.A.',
#  'nOriginal': 1,
#  'nRT': 0,
#  'nRTin': 0,
#  'nTotal': 1,
#  'name': 'Hamzah Saman',
#  'nquotein': 0,
#  'nreplyin': 0,
#  'ntweets': 3256,
#  'screen_name': 'HamzahSaman',
#  'verified': False}
# ********************************************************************************
# {'_id': '60857185',
#  'created_at': {'date': '2009-07-28T09:11:20Z'},
#  'followers': 7610,
#  'friends_count': 139,
#  'geo_enabled': True,
#  'location': 'PH ✈️LA',
#  'nOriginal': 1,
#  'nRT': 0,
#  'nRTin': 0,
#  'nTotal': 1,
#  'name': 'J Rey Soul',
#  'nquotein': 0,
#  'nreplyin': 0,
#  'ntweets': 11787,
#  'screen_name': 'JReysoul',
#  'verified': False}
# ********************************************************************************
# {'_id': '63335631',
#  'created_at': {'date': '2009-08-06T02:08:30Z'},
#  'followers': 235774,
#  'friends_count': 17472,
#  'geo_enabled': True,
#  'location': 'Los Angeles, CA',
#  'nOriginal': 153,
#  'nRT': 82,
#  'nRTin': 12726,
#  'nTotal': 235,
#  'name': 'Joy Villa',
#  'nquotein': 6947,
#  'nreplyin': 1874,
#  'ntweets': 48706,
#  'screen_name': 'Joy_Villa',
#  'verified': True}
# ********************************************************************************
# {'_id': '145807333',
#  'created_at': {'date': '2010-05-19T23:02:06Z'},
#  'followers': 810,
#  'friends_count': 1257,
#  'geo_enabled': True,
#  'location': 'Los Angeles, CA',
#  'nOriginal': 1,
#  'nRT': 0,
#  'nRTin': 0,
#  'nTotal': 1,
#  'name': 'Bradley H Denniston',
#  'nquotein': 0,
#  'nreplyin': 0,
#  'ntweets': 3398,
#  'screen_name': 'mr_hugh_prod',
#  'verified': False}
# ********************************************************************************
# {'_id': '89170628',
#  'created_at': {'date': '2009-11-11T12:11:45Z'},
#  'followers': 495,
#  'friends_count': 334,
#  'geo_enabled': True,
#  'location': 'Everywhere',
#  'nOriginal': 1,
#  'nRT': 0,
#  'nRTin': 0,
#  'nTotal': 1,
#  'name': 'Carla Kemp',
#  'nquotein': 0,
#  'nreplyin': 0,
#  'ntweets': 5967,
#  'screen_name': 'fabNfitByCarla',
#  'verified': False}
# ********************************************************************************
# {'_id': '43740548',
#  'created_at': {'date': '2009-05-31T19:33:50Z'},
#  'followers': 79,
#  'friends_count': 144,
#  'geo_enabled': True,
#  'location': 'New York',
#  'nOriginal': 8,
#  'nRT': 0,
#  'nRTin': 0,
#  'nTotal': 8,
#  'name': 'Taylor Schon',
#  'nquotein': 0,
#  'nreplyin': 0,
#  'ntweets': 4544,
#  'screen_name': 'Tayzlor',
#  'verified': False}
# ********************************************************************************
# {'_id': '49147420',
#  'created_at': {'date': '2009-06-20T22:47:46Z'},
#  'followers': 471,
#  'friends_count': 1043,
#  'geo_enabled': True,
#  'location': 'Los Angeles, CA',
#  'nOriginal': 1,
#  'nRT': 0,
#  'nRTin': 0,
#  'nTotal': 1,
#  'name': 'Charles Anthony',
#  'nquotein': 0,
#  'nreplyin': 0,
#  'ntweets': 6496,
#  'screen_name': 'ChatTeaCharles',
#  'verified': False}
# ********************************************************************************
# {'_id': '1977707425',
#  'created_at': {'date': '2013-10-21T06:32:42Z'},
#  'followers': 29541,
#  'friends_count': 152,
#  'geo_enabled': True,
#  'location': 'Las Vegas, Nevada',
#  'nOriginal': 12,
#  'nRT': 5,
#  'nRTin': 1,
#  'nTotal': 17,
#  'name': 'Alexander Jokinsky',
#  'nquotein': 0,
#  'nreplyin': 1,
#  'ntweets': 7987,
#  'screen_name': 'AJokinsky',
#  'verified': False}
# ********************************************************************************
# {'_id': '119778127',
#  'created_at': {'date': '2010-03-04T16:29:58Z'},
#  'followers': 242,
#  'friends_count': 473,
#  'geo_enabled': True,
#  'location': 'Los Angeles, California',
#  'nOriginal': 2,
#  'nRT': 0,
#  'nRTin': 0,
#  'nTotal': 2,
#  'name': 'Angel City TV',
#  'nquotein': 0,
#  'nreplyin': 0,
#  'ntweets': 7636,
#  'screen_name': 'AngelCityTV',
#  'verified': False}
# ********************************************************************************
# {'_id': '14063510',
#  'created_at': {'date': '2008-03-01T03:45:25Z'},
#  'followers': 739,
#  'friends_count': 1540,
#  'geo_enabled': True,
#  'location': 'San Dimas, CA',
#  'nOriginal': 6,
#  'nRT': 2,
#  'nRTin': 0,
#  'nTotal': 8,
#  'name': 'Diane McClure',
#  'nquotein': 0,
#  'nreplyin': 0,
#  'ntweets': 10578,
#  'screen_name': 'dmccluredvm',
#  'verified': False}
# ********************************************************************************
# {'_id': '266421915',
#  'created_at': {'date': '2011-03-15T06:01:19Z'},
#  'followers': 12404,
#  'friends_count': 9909,
#  'geo_enabled': True,
#  'location': 'Los Angeles',
#  'nOriginal': 5,
#  'nRT': 2,
#  'nRTin': 0,
#  'nTotal': 7,
#  'name': 'LaReine Chabut',
#  'nquotein': 0,
#  'nreplyin': 0,
#  'ntweets': 2836,
#  'screen_name': 'LaReineChabut',
#  'verified': False}
# ********************************************************************************
# {'_id': '335413589',
#  'created_at': {'date': '2011-07-14T17:05:07Z'},
#  'followers': 185,
#  'friends_count': 240,
#  'geo_enabled': True,
#  'location': 'USA/COL ',
#  'nOriginal': 1,
#  'nRT': 0,
#  'nRTin': 0,
#  'nTotal': 1,
#  'name': 'Felipe Forero',
#  'nquotein': 0,
#  'nreplyin': 0,
#  'ntweets': 3791,
#  'screen_name': 'pabloprince101',
#  'verified': False}
# ********************************************************************************
# {'_id': '14480889',
#  'created_at': {'date': '2008-04-22T21:37:37Z'},
#  'followers': 5243,
#  'friends_count': 796,
#  'geo_enabled': True,
#  'location': 'DAFT.',
#  'nOriginal': 7,
#  'nRT': 1,
#  'nRTin': 1,
#  'nTotal': 8,
#  'name': 'glenjamn',
#  'nquotein': 0,
#  'nreplyin': 0,
#  'ntweets': 18616,
#  'screen_name': 'glenjamn',
#  'verified': False}
# ********************************************************************************
# {'_id': '29318226',
#  'created_at': {'date': '2009-04-06T23:01:41Z'},
#  'followers': 1404,
#  'friends_count': 680,
#  'geo_enabled': True,
#  'location': "It's ALL in My minds eye.",
#  'nOriginal': 1,
#  'nRT': 0,
#  'nRTin': 0,
#  'nTotal': 1,
#  'name': '❇ RickSynergy ❇',
#  'nquotein': 0,
#  'nreplyin': 0,
#  'ntweets': 18505,
#  'screen_name': 'SirPaganini',
#  'verified': False}
# ********************************************************************************
# {'_id': '1145724810942717953',
#  'created_at': {'date': '2019-07-01T16:04:16Z'},
#  'followers': 7,
#  'friends_count': 149,
#  'geo_enabled': True,
#  'location': None,
#  'nOriginal': 7,
#  'nRT': 0,
#  'nRTin': 0,
#  'nTotal': 7,
#  'name': 'Brittany De Kine',
#  'nquotein': 2,
#  'nreplyin': 0,
#  'ntweets': 1056,
#  'screen_name': 'kine_brittany',
#  'verified': False}
# ********************************************************************************
# {'_id': '50966493',
#  'created_at': {'date': '2009-06-26T07:42:59Z'},
#  'followers': 504,
#  'friends_count': 2154,
#  'geo_enabled': True,
#  'location': 'Norwalk, CA',
#  'nOriginal': 2,
#  'nRT': 0,
#  'nRTin': 0,
#  'nTotal': 2,
#  'name': 'JimboSlice',
#  'nquotein': 0,
#  'nreplyin': 0,
#  'ntweets': 11849,
#  'screen_name': 'JIMBO__SLICE88',
#  'verified': False}
# ********************************************************************************
# {'_id': '20734169',
#  'created_at': {'date': '2009-02-13T00:10:25Z'},
#  'followers': 307,
#  'friends_count': 591,
#  'geo_enabled': True,
#  'location': ' California',
#  'nOriginal': 3,
#  'nRT': 1,
#  'nRTin': 0,
#  'nTotal': 4,
#  'name': 'Coach Greg Gastelum',
#  'nquotein': 0,
#  'nreplyin': 0,
#  'ntweets': 6401,
#  'screen_name': 'GregGastelum',
#  'verified': False}
# ********************************************************************************
# {'_id': '55351351',
#  'created_at': {'date': '2009-07-09T20:27:04Z'},
#  'followers': 576383,
#  'friends_count': 6137,
#  'geo_enabled': True,
#  'location': 'United States',
#  'nOriginal': 23,
#  'nRT': 4,
#  'nRTin': 675,
#  'nTotal': 27,
#  'name': 'Tito Ortiz',
#  'nquotein': 51,
#  'nreplyin': 162,
#  'ntweets': 29071,
#  'screen_name': 'titoortiz',
#  'verified': True}
# ********************************************************************************
# {'_id': '738093895309893632',
#  'created_at': {'date': '2016-06-01T19:44:32Z'},
#  'followers': 1574,
#  'friends_count': 223,
#  'geo_enabled': True,
#  'location': 'Los Angeles, CA',
#  'nOriginal': 17,
#  'nRT': 29,
#  'nRTin': 6,
#  'nTotal': 46,
#  'name': 'Zacharias Abel',
#  'nquotein': 1,
#  'nreplyin': 0,
#  'ntweets': 3931,
#  'screen_name': 'zachariasabel',
#  'verified': False}
# ********************************************************************************
# {'_id': '55040542',
#  'created_at': {'date': '2009-07-08T21:47:33Z'},
#  'followers': 928,
#  'friends_count': 1194,
#  'geo_enabled': True,
#  'location': 'Anaheim, CA',
#  'nOriginal': 5,
#  'nRT': 15,
#  'nRTin': 0,
#  'nTotal': 20,
#  'name': 'Sean Deyo',
#  'nquotein': 0,
#  'nreplyin': 2,
#  'ntweets': 58663,
#  'screen_name': 'DaddyDeyo',
#  'verified': False}
# ********************************************************************************
# {'_id': '245963716',
#  'created_at': {'date': '2011-02-01T20:59:30Z'},
#  'followers': 790078,
#  'friends_count': 169,
#  'geo_enabled': True,
#  'location': 'Washington, DC',
#  'nOriginal': 24,
#  'nRT': 0,
#  'nRTin': 8780,
#  'nTotal': 24,
#  'name': 'Tiffany Ariana Trump',
#  'nquotein': 385,
#  'nreplyin': 2335,
#  'ntweets': 860,
#  'screen_name': 'TiffanyATrump',
#  'verified': True}
# ********************************************************************************
# {'_id': '766484140539645952',
#  'created_at': {'date': '2016-08-19T03:57:14Z'},
#  'followers': 1059,
#  'friends_count': 2995,
#  'geo_enabled': True,
#  'location': 'Whittier, CA',
#  'nOriginal': 5,
#  'nRT': 0,
#  'nRTin': 0,
#  'nTotal': 5,
#  'name': 'O.G.L.A.RAMS FAN',
#  'nquotein': 0,
#  'nreplyin': 0,
#  'ntweets': 21258,
#  'screen_name': 'oglaramsfan',
#  'verified': False}
# ********************************************************************************
# {'_id': '2364892399',
#  'created_at': {'date': '2014-02-28T01:32:15Z'},
#  'followers': 776,
#  'friends_count': 445,
#  'geo_enabled': True,
#  'location': 'Los Angeles, CA',
#  'nOriginal': 1,
#  'nRT': 0,
#  'nRTin': 0,
#  'nTotal': 1,
#  'name': 'Please Do Not Enter',
#  'nquotein': 0,
#  'nreplyin': 0,
#  'ntweets': 2024,
#  'screen_name': 'PlsDoNotEnter',
#  'verified': False}
# ********************************************************************************
# {'_id': '915328484406312960',
#  'created_at': {'date': '2017-10-03T21:31:31Z'},
#  'followers': 5301,
#  'friends_count': 3247,
#  'geo_enabled': True,
#  'location': 'California, USA',
#  'nOriginal': 11,
#  'nRT': 1,
#  'nRTin': 3,
#  'nTotal': 12,
#  'name': 'Edwin Duterte (Opportunity Matters)',
#  'nquotein': 0,
#  'nreplyin': 0,
#  'ntweets': 5992,
#  'screen_name': 'DuterteCA',
#  'verified': False}
# ********************************************************************************
# {'_id': '2325789620',
#  'created_at': {'date': '2014-02-03T17:22:08Z'},
#  'followers': 275,
#  'friends_count': 552,
#  'geo_enabled': True,
#  'location': 'Newport Beach, CA 92660',
#  'nOriginal': 1,
#  'nRT': 0,
#  'nRTin': 0,
#  'nTotal': 1,
#  'name': 'OC Home & Family',
#  'nquotein': 0,
#  'nreplyin': 0,
#  'ntweets': 1442,
#  'screen_name': 'OCHomeAndFamily',
#  'verified': False}
# ********************************************************************************
# {'_id': '92445675',
#  'created_at': {'date': '2009-11-25T04:25:17Z'},
#  'followers': 392,
#  'friends_count': 2401,
#  'geo_enabled': True,
#  'location': None,
#  'nOriginal': 1,
#  'nRT': 0,
#  'nRTin': 0,
#  'nTotal': 1,
#  'name': 'Longhorn4Life',
#  'nquotein': 0,
#  'nreplyin': 0,
#  'ntweets': 3885,
#  'screen_name': 'UTHornsRule',
#  'verified': False}
# ********************************************************************************
# {'_id': '3283991822',
#  'created_at': {'date': '2015-07-19T04:55:51Z'},
#  'followers': 224,
#  'friends_count': 1139,
#  'geo_enabled': True,
#  'location': 'WHERE SUCCESS IS KEY!!!',
#  'nOriginal': 6,
#  'nRT': 0,
#  'nRTin': 0,
#  'nTotal': 6,
#  'name': 'Chrissy Heart',
#  'nquotein': 0,
#  'nreplyin': 1,
#  'ntweets': 4675,
#  'screen_name': 'ItzCBreezy143',
#  'verified': False}
# ********************************************************************************
# {'_id': '96702567',
#  'created_at': {'date': '2009-12-14T05:35:04Z'},
#  'followers': 1170,
#  'friends_count': 1000,
#  'geo_enabled': True,
#  'location': 'Kansas + Arizona + California ',
#  'nOriginal': 23,
#  'nRT': 14,
#  'nRTin': 29,
#  'nTotal': 37,
#  'name': 'Jennifer Grøndahl 😷',
#  'nquotein': 3,
#  'nreplyin': 3,
#  'ntweets': 14129,
#  'screen_name': 'JennyGrondahl',
#  'verified': False}
# ********************************************************************************
# {'_id': '424632251',
#  'created_at': {'date': '2011-11-30T00:46:59Z'},
#  'followers': 19,
#  'friends_count': 96,
#  'geo_enabled': True,
#  'location': 'Tustin, CA',
#  'nOriginal': 13,
#  'nRT': 6,
#  'nRTin': 9,
#  'nTotal': 19,
#  'name': 'sunsue tamai',
#  'nquotein': 17,
#  'nreplyin': 4,
#  'ntweets': 52,
#  'screen_name': 'SuN4lUvS',
#  'verified': False}
# ********************************************************************************
# {'_id': '930506287',
#  'created_at': {'date': '2012-11-06T20:36:16Z'},
#  'followers': 507,
#  'friends_count': 1407,
#  'geo_enabled': True,
#  'location': 'United States',
#  'nOriginal': 1,
#  'nRT': 0,
#  'nRTin': 0,
#  'nTotal': 1,
#  'name': 'qusay tariq',
#  'nquotein': 0,
#  'nreplyin': 0,
#  'ntweets': 34475,
#  'screen_name': 'AcadmeS',
#  'verified': False}
# ********************************************************************************
# {'_id': '1135616035191582720',
#  'created_at': {'date': '2019-06-03T18:35:36Z'},
#  'followers': 72,
#  'friends_count': 568,
#  'geo_enabled': True,
#  'location': 'California, USA',
#  'nOriginal': 3,
#  'nRT': 0,
#  'nRTin': 0,
#  'nTotal': 3,
#  'name': 'shadeeboe',
#  'nquotein': 0,
#  'nreplyin': 0,
#  'ntweets': 971,
#  'screen_name': 'shadeeboe',
#  'verified': False}
# ********************************************************************************
# {'_id': '175281443',
#  'created_at': {'date': '2010-08-06T04:52:36Z'},
#  'followers': 407,
#  'friends_count': 577,
#  'geo_enabled': True,
#  'location': 'San Diego',
#  'nOriginal': 3,
#  'nRT': 1,
#  'nRTin': 0,
#  'nTotal': 4,
#  'name': 'SD Master Trainer',
#  'nquotein': 0,
#  'nreplyin': 0,
#  'ntweets': 54050,
#  'screen_name': 'MariusSose',
#  'verified': False}
# ********************************************************************************
# {'_id': '632227049',
#  'created_at': {'date': '2012-07-10T18:59:16Z'},
#  'followers': 57,
#  'friends_count': 111,
#  'geo_enabled': True,
# ...
# {'_id': '339666877',
#  'created_at': {'date': '2011-07-21T13:26:37Z'},
#  'followers': 501,
#  'friends_count': 376,
#  'geo_enabled': True,
#  'location': 'Brooklyn, NY',
#  'nOriginal': 1,
#  'nRT': 0,
#  'nRTin': 0,
#  'nTotal': 1,
#  'name': 'Sarah🎃Boootright👻',
#  'nquotein': 0,
#  'nreplyin': 0,
#  'ntweets': 3318,
#  'screen_name': 'sarahboatright',
#  'verified': False}
# ********************************************************************************
# {'_id': '977818573',
#  'created_at': {'date': '2012-11-29T07:27:29Z'},
#  'followers': 91302,
#  'friends_count': 5419,
#  'geo_enabled': True,
#  'location': '91r.Faubourg St-Honoré, Paris',
#  'nOriginal': 6,
#  'nRT': 0,
#  'nRTin': 0,
#  'nTotal': 6,
#  'name': 'ALEXANDRE BEAUVAIS-CHIVA ☨ 🇫🇷🇷🇴🇪🇺🇺🇳',
#  'nquotein': 1,
#  'nreplyin': 0,
#  'ntweets': 20958,
#  'screen_name': 'albeauvaischiva',
#  'verified': False}
# ********************************************************************************
# {'_id': '11584152',
#  'created_at': {'date': '2007-12-27T23:42:19Z'},
#  'followers': 134,
#  'friends_count': 192,
#  'geo_enabled': True,
#  'location': 'Brugge',
#  'nOriginal': 2,
#  'nRT': 1,
#  'nRTin': 0,
#  'nTotal': 3,
#  'name': 'Jeroen',
#  'nquotein': 0,
#  'nreplyin': 0,
#  'ntweets': 2224,
#  'screen_name': 'zerre',
#  'verified': False}
# ********************************************************************************
# {'_id': '60288592',
#  'created_at': {'date': '2009-07-26T11:43:11Z'},
#  'followers': 12176,
#  'friends_count': 2070,
#  'geo_enabled': True,
#  'location': 'Nigeria',
#  'nOriginal': 3,
#  'nRT': 2,
#  'nRTin': 1,
#  'nTotal': 5,
#  'name': 'GHETTO CHILD',
#  'nquotein': 0,
#  'nreplyin': 0,
#  'ntweets': 30422,
#  'screen_name': 'Blackfacenaija',
#  'verified': False}
# ********************************************************************************
# {'_id': '319558592',
#  'created_at': {'date': '2011-06-18T09:53:53Z'},
#  'followers': 9,
#  'friends_count': 214,
#  'geo_enabled': True,
#  'location': 'Luxembourg',
#  'nOriginal': 1,
#  'nRT': 0,
#  'nRTin': 1,
#  'nTotal': 1,
#  'name': 'João Alegre',
#  'nquotein': 0,
#  'nreplyin': 0,
#  'ntweets': 57,
#  'screen_name': 'joaoalegre1',
#  'verified': False}
# ********************************************************************************
# {'_id': '25812895',
#  'created_at': {'date': '2009-03-22T12:39:07Z'},
#  'followers': 168,
#  'friends_count': 294,
#  'geo_enabled': True,
#  'location': 'Groningen, the Netherlands',
#  'nOriginal': 1,
#  'nRT': 0,
#  'nRTin': 0,
#  'nTotal': 1,
#  'name': 'Michel Willems',
#  'nquotein': 0,
#  'nreplyin': 0,
#  'ntweets': 8724,
#  'screen_name': 'tafkap72',
#  'verified': False}
# ********************************************************************************
# {'_id': '818419735486296064',
#  'created_at': {'date': '2017-01-09T11:30:45Z'},
#  'followers': 648,
#  'friends_count': 1575,
#  'geo_enabled': True,
#  'location': 'Ghana',
#  'nOriginal': 1,
#  'nRT': 0,
#  'nRTin': 0,
#  'nTotal': 1,
#  'name': 'Aki Billy',
#  'nquotein': 0,
#  'nreplyin': 0,
#  'ntweets': 767,
#  'screen_name': 'Akibilly1',
#  'verified': False}
# ********************************************************************************
# {'_id': '284700392',
#  'created_at': {'date': '2011-04-19T20:04:35Z'},
#  'followers': 431,
#  'friends_count': 439,
#  'geo_enabled': True,
#  'location': 'Abuja, Nigeria',
#  'nOriginal': 5,
#  'nRT': 0,
#  'nRTin': 0,
#  'nTotal': 5,
#  'name': 'Dickson Iroegbu✍',
#  'nquotein': 0,
#  'nreplyin': 0,
#  'ntweets': 2284,
#  'screen_name': 'dicksoniroegbu',
#  'verified': False}
# ********************************************************************************
# {'_id': '1662336361',
#  'created_at': {'date': '2013-08-11T11:17:04Z'},
#  'followers': 356,
#  'friends_count': 502,
#  'geo_enabled': True,
#  'location': 'Nigeria',
#  'nOriginal': 1,
#  'nRT': 0,
#  'nRTin': 0,
#  'nTotal': 1,
#  'name': 'Daniel',
#  'nquotein': 0,
#  'nreplyin': 0,
#  'ntweets': 1646,
#  'screen_name': 'officialdansino',
#  'verified': False}
# ********************************************************************************
# {'_id': '30654634',
#  'created_at': {'date': '2009-04-12T14:11:05Z'},
#  'followers': 389,
#  'friends_count': 801,
#  'geo_enabled': True,
#  'location': 'Zürich ',
#  'nOriginal': 1,
#  'nRT': 0,
#  'nRTin': 0,
#  'nTotal': 1,
#  'name': 'Shamol Majumder',
#  'nquotein': 0,
#  'nreplyin': 0,
#  'ntweets': 4697,
#  'screen_name': 'Shamol',
#  'verified': False}
# ********************************************************************************
# {'_id': '1473364880',
#  'created_at': {'date': '2013-05-31T23:49:13Z'},
#  'followers': 1855,
#  'friends_count': 4968,
#  'geo_enabled': True,
#  'location': 'SF, CA - USA - Earth',
#  'nOriginal': 3,
#  'nRT': 12,
#  'nRTin': 0,
#  'nTotal': 15,
#  'name': 'Stardog97',
#  'nquotein': 0,
#  'nreplyin': 1,
#  'ntweets': 44810,
#  'screen_name': 'Stardog97',
#  'verified': False}
# ********************************************************************************
# {'_id': '1265953364069793794',
#  'created_at': {'date': '2020-05-28T10:31:01Z'},
#  'followers': 16,
#  'friends_count': 351,
#  'geo_enabled': True,
#  'location': 'Allgäu, Germany 🇩🇪',
#  'nOriginal': 1,
#  'nRT': 0,
#  'nRTin': 0,
#  'nTotal': 1,
#  'name': 'gyrusinczky',
#  'nquotein': 0,
#  'nreplyin': 0,
#  'ntweets': 82,
#  'screen_name': 'gyrusinczky',
#  'verified': False}
# ********************************************************************************
# {'_id': '76302936',
#  'created_at': {'date': '2009-09-22T10:51:29Z'},
#  'followers': 260,
#  'friends_count': 372,
#  'geo_enabled': True,
#  'location': 'Malmö',
#  'nOriginal': 1,
#  'nRT': 0,
#  'nRTin': 0,
#  'nTotal': 1,
#  'name': 'MattiasHindersonVEVO',
#  'nquotein': 0,
#  'nreplyin': 0,
#  'ntweets': 23667,
#  'screen_name': 'hinderson',
#  'verified': False}
# ********************************************************************************
# {'_id': '147667824',
#  'created_at': {'date': '2010-05-24T18:51:56Z'},
#  'followers': 94,
#  'friends_count': 201,
#  'geo_enabled': True,
#  'location': 'Täby & Hemsjö, Bräcke, Sweden',
#  'nOriginal': 4,
#  'nRT': 1,
#  'nRTin': 0,
#  'nTotal': 5,
#  'name': 'Mats Wilhelmsson',
#  'nquotein': 0,
#  'nreplyin': 0,
#  'ntweets': 4528,
#  'screen_name': 'nyywille',
#  'verified': False}
# ********************************************************************************
# {'_id': '26604996',
#  'created_at': {'date': '2009-03-25T22:04:55Z'},
#  'followers': 608,
#  'friends_count': 702,
#  'geo_enabled': True,
#  'location': '59.62290,17.85853',
#  'nOriginal': 1,
#  'nRT': 1,
#  'nRTin': 0,
#  'nTotal': 2,
#  'name': 'Kev Meredith',
#  'nquotein': 0,
#  'nreplyin': 0,
#  'ntweets': 120956,
#  'screen_name': 'KymriskaDraken',
#  'verified': False}
# ********************************************************************************
# {'_id': '18549724',
#  'created_at': {'date': '2009-01-02T10:14:07Z'},
#  'followers': 672196,
#  'friends_count': 2680,
#  'geo_enabled': True,
#  'location': None,
#  'nOriginal': 6,
#  'nRT': 0,
#  'nRTin': 3,
#  'nTotal': 6,
#  'name': 'Carl Bildt',
#  'nquotein': 9,
#  'nreplyin': 2,
#  'ntweets': 22869,
#  'screen_name': 'carlbildt',
#  'verified': True}
# ********************************************************************************
# {'_id': '1316862031',
#  'created_at': {'date': '2013-03-30T17:25:49Z'},
#  'followers': 518,
#  'friends_count': 438,
#  'geo_enabled': True,
#  'location': 'Warszawa, Polska',
#  'nOriginal': 69,
#  'nRT': 0,
#  'nRTin': 1,
#  'nTotal': 69,
#  'name': '𝔓𝔦𝔬𝔱𝔯 𝔇𝔶𝔟𝔦𝔢𝔠',
#  'nquotein': 0,
#  'nreplyin': 0,
#  'ntweets': 578938,
#  'screen_name': 'pidybi',
#  'verified': False}
# ********************************************************************************
# {'_id': '18478716',
#  'created_at': {'date': '2008-12-30T15:05:51Z'},
#  'followers': 1020,
#  'friends_count': 1231,
#  'geo_enabled': True,
#  'location': 'Warsaw, Poland',
#  'nOriginal': 7,
#  'nRT': 1,
#  'nRTin': 0,
#  'nTotal': 8,
#  'name': 'Sethai / Konradobah',
#  'nquotein': 0,
#  'nreplyin': 1,
#  'ntweets': 76947,
#  'screen_name': 'Sethai',
#  'verified': False}
# ********************************************************************************
# {'_id': '15880647',
#  'created_at': {'date': '2008-08-17T08:36:58Z'},
#  'followers': 2231,
#  'friends_count': 3043,
#  'geo_enabled': True,
#  'location': 'Helsinki, Finland',
#  'nOriginal': 2,
#  'nRT': 3,
#  'nRTin': 0,
#  'nTotal': 5,
#  'name': '(((JyrkiWahlstedt)))',
#  'nquotein': 0,
#  'nreplyin': 0,
#  'ntweets': 57442,
#  'screen_name': 'jyrkiw',
#  'verified': False}
# ********************************************************************************
# {'_id': '1100519265424236545',
#  'created_at': {'date': '2019-02-26T22:13:34Z'},
#  'followers': 4,
#  'friends_count': 37,
#  'geo_enabled': True,
#  'location': 'Phoenix, AZ',
#  'nOriginal': 1,
#  'nRT': 0,
#  'nRTin': 0,
#  'nTotal': 1,
#  'name': 'NORBERTO_NEXUS',
#  'nquotein': 0,
#  'nreplyin': 0,
#  'ntweets': 172,
#  'screen_name': 'NexusNorberto',
#  'verified': False}
# ********************************************************************************
# {'_id': '1088729740930936832',
#  'created_at': {'date': '2019-01-25T09:26:12Z'},
#  'followers': 24,
#  'friends_count': 95,
#  'geo_enabled': True,
#  'location': 'İstanbul, Türkiye',
#  'nOriginal': 1,
#  'nRT': 1,
#  'nRTin': 1,
#  'nTotal': 2,
#  'name': 'Abdi Abdu',
#  'nquotein': 0,
#  'nreplyin': 0,
#  'ntweets': 70,
#  'screen_name': 'Cabdull13822073',
#  'verified': False}
# ********************************************************************************
# {'_id': '1018027067521339392',
#  'created_at': {'date': '2018-07-14T06:59:01Z'},
#  'followers': 11,
#  'friends_count': 58,
#  'geo_enabled': True,
#  'location': 'Nairobi, Kenya',
#  'nOriginal': 1,
#  'nRT': 0,
#  'nRTin': 1,
#  'nTotal': 1,
#  'name': 'DAVID BRAINARD ONEYA',
#  'nquotein': 0,
#  'nreplyin': 0,
#  'ntweets': 15,
#  'screen_name': 'DavidOneya',
#  'verified': False}
# ********************************************************************************
# {'_id': '2388075212',
#  'created_at': {'date': '2014-03-13T23:40:09Z'},
#  'followers': 53397,
#  'friends_count': 2729,
#  'geo_enabled': True,
#  'location': None,
#  'nOriginal': 3,
#  'nRT': 0,
#  'nRTin': 0,
#  'nTotal': 3,
#  'name': 'Liveuamap',
#  'nquotein': 3,
#  'nreplyin': 0,
#  'ntweets': 55222,
#  'screen_name': 'Liveuamap',
#  'verified': True}
# ********************************************************************************
# {'_id': '23041607',
#  'created_at': {'date': '2009-03-06T07:18:56Z'},
#  'followers': 768,
#  'friends_count': 85,
#  'geo_enabled': True,
#  'location': 'Redondo Beach, CA',
#  'nOriginal': 6,
#  'nRT': 3,
#  'nRTin': 1,
#  'nTotal': 9,
#  'name': 'Sean J. Kelleher',
#  'nquotein': 0,
#  'nreplyin': 0,
#  'ntweets': 74274,
#  'screen_name': 'SeanKelleher',
#  'verified': False}
# ********************************************************************************
# {'_id': '2682473454',
#  'created_at': {'date': '2014-07-26T14:32:13Z'},
#  'followers': 61,
#  'friends_count': 278,
#  'geo_enabled': True,
#  'location': 'المنيا, مصر',
#  'nOriginal': 1,
#  'nRT': 0,
#  'nRTin': 0,
#  'nTotal': 1,
#  'name': 'Ahmed Mohamed أحمد محمد',
#  'nquotein': 0,
#  'nreplyin': 0,
#  'ntweets': 7207,
#  'screen_name': 'VAVOR_NT',
#  'verified': False}
# ********************************************************************************
# {'_id': '114830093',
#  'created_at': {'date': '2010-02-16T19:02:34Z'},
#  'followers': 46,
#  'friends_count': 117,
#  'geo_enabled': True,
#  'location': 'Los Angeles',
#  'nOriginal': 1,
#  'nRT': 0,
#  'nRTin': 0,
#  'nTotal': 1,
#  'name': 'Manolitto',
#  'nquotein': 0,
#  'nreplyin': 0,
#  'ntweets': 382,
#  'screen_name': 'manolitto68',
#  'verified': False}
# ********************************************************************************
# {'_id': '1083261919178436608',
#  'created_at': {'date': '2019-01-10T07:19:02Z'},
#  'followers': 188,
#  'friends_count': 99,
#  'geo_enabled': True,
#  'location': 'Pakistan',
#  'nOriginal': 1,
#  'nRT': 0,
#  'nRTin': 0,
#  'nTotal': 1,
#  'name': 'HiDaYaT_KhaN_KhiLjii',
#  'nquotein': 0,
#  'nreplyin': 0,
#  'ntweets': 1629,
#  'screen_name': 'WajH_TuM_H0',
#  'verified': False}
# ********************************************************************************
# {'_id': '1237329858235154438',
#  'created_at': {'date': '2020-03-10T10:50:23Z'},
#  'followers': 20,
#  'friends_count': 125,
#  'geo_enabled': True,
#  'location': None,
#  'nOriginal': 1,
#  'nRT': 0,
#  'nRTin': 0,
#  'nTotal': 1,
#  'name': '#Endsarnow',
#  'nquotein': 0,
#  'nreplyin': 0,
#  'ntweets': 245,
#  'screen_name': 'GraphianTv',
#  'verified': False}
# ********************************************************************************
# {'_id': '736591740',
#  'created_at': {'date': '2012-08-04T11:41:55Z'},
#  'followers': 356,
#  'friends_count': 236,
#  'geo_enabled': True,
#  'location': 'Always on the move',
#  'nOriginal': 1,
#  'nRT': 0,
#  'nRTin': 0,
#  'nTotal': 1,
#  'name': 'Michael Bromfield',
#  'nquotein': 0,
#  'nreplyin': 0,
#  'ntweets': 8668,
#  'screen_name': 'notesfromanomad',
#  'verified': False}
# ********************************************************************************
# {'_id': '366754899',
#  'created_at': {'date': '2011-09-02T19:19:39Z'},
#  'followers': 3122,
#  'friends_count': 925,
#  'geo_enabled': True,
#  'location': 'Alabama, USA',
#  'nOriginal': 1,
#  'nRT': 0,
#  'nRTin': 0,
#  'nTotal': 1,
#  'name': 'Mechi',
#  'nquotein': 0,
#  'nreplyin': 0,
#  'ntweets': 17526,
#  'screen_name': 'NoLabelMechi',
#  'verified': False}
# ********************************************************************************
# {'_id': '65339360',
#  'created_at': {'date': '2009-08-13T11:09:52Z'},
#  'followers': 453,
#  'friends_count': 350,
#  'geo_enabled': True,
#  'location': 'worldwide',
#  'nOriginal': 1,
#  'nRT': 0,
#  'nRTin': 0,
#  'nTotal': 1,
#  'name': 'Smashing Sebastian H',
#  'nquotein': 0,
#  'nreplyin': 0,
#  'ntweets': 5230,
#  'screen_name': 'smashingsebasti',
#  'verified': False}
# ********************************************************************************
# {'_id': '52035968',
#  'created_at': {'date': '2009-06-29T12:04:03Z'},
#  'followers': 265,
#  'friends_count': 889,
#  'geo_enabled': True,
#  'location': "Shanghai, People's Republic of",
#  'nOriginal': 2,
#  'nRT': 0,
#  'nRTin': 0,
#  'nTotal': 2,
#  'name': 'Henry Liu',
#  'nquotein': 0,
#  'nreplyin': 0,
#  'ntweets': 2553,
#  'screen_name': 'Likekimchi',
#  'verified': False}
# ********************************************************************************
# {'_id': '17981271',
#  'created_at': {'date': '2008-12-09T02:28:03Z'},
#  'followers': 149,
#  'friends_count': 1061,
#  'geo_enabled': True,
#  'location': 'Glenelg North, Adelaide',
#  'nOriginal': 4,
#  'nRT': 0,
#  'nRTin': 0,
#  'nTotal': 4,
#  'name': 'Swansong_For_A_Raven',
#  'nquotein': 0,
#  'nreplyin': 1,
#  'ntweets': 5813,
#  'screen_name': 'Tommy_Gunn_Sixx',
#  'verified': False}
# ********************************************************************************
# {'_id': '425745249',
#  'created_at': {'date': '2011-12-01T11:21:59Z'},
#  'followers': 370,
#  'friends_count': 852,
#  'geo_enabled': True,
#  'location': 'Adelaide, South Australia',
#  'nOriginal': 1,
#  'nRT': 0,
#  'nRTin': 0,
#  'nTotal': 1,
#  'name': 'Tarun Raman',
#  'nquotein': 0,
#  'nreplyin': 0,
#  'ntweets': 11915,
#  'screen_name': 'raman_tarun',
#  'verified': False}
# ********************************************************************************
# {'_id': '2985069895',
#  'created_at': {'date': '2015-01-16T03:37:44Z'},
#  'followers': 73,
#  'friends_count': 488,
#  'geo_enabled': True,
#  'location': 'Melbourne, Victoria',
#  'nOriginal': 1,
#  'nRT': 0,
#  'nRTin': 0,
#  'nTotal': 1,
#  'name': 'BYST Sime Thornton',
#  'nquotein': 0,
#  'nreplyin': 0,
#  'ntweets': 2113,
#  'screen_name': 'ThorntonSime',
#  'verified': False}
# ********************************************************************************
# {'_id': '65166389',
#  'created_at': {'date': '2009-08-12T21:25:09Z'},
#  'followers': 1162,
#  'friends_count': 999,
#  'geo_enabled': True,
#  'location': 'auckland',
#  'nOriginal': 1,
#  'nRT': 0,
#  'nRTin': 0,
#  'nTotal': 1,
#  'name': 'Murry Tweetpants',
#  'nquotein': 0,
#  'nreplyin': 0,
#  'ntweets': 10094,
#  'screen_name': 'msweetpants',
#  'verified': False}
# ********************************************************************************
# {'_id': '7800292',
#  'created_at': {'date': '2007-07-29T11:41:09Z'},
#  'followers': 2062,
#  'friends_count': 1867,
#  'geo_enabled': True,
#  'location': '-41.222841,175.469116',
#  'nOriginal': 2,
#  'nRT': 0,
#  'nRTin': 0,
#  'nTotal': 2,
#  'name': '𝙺𝚒𝚖 𝙿𝚘𝚝𝚝𝚎𝚛 🎸',
#  'nquotein': 0,
#  'nreplyin': 1,
#  'ntweets': 19854,
#  'screen_name': 'kimpotter',
#  'verified': False}
# ********************************************************************************

# %% [markdown]
# Queremos escribir un código que nos muestre los tweets de un usuario a partir de su nombre (`name` en `user`). Para ello primero deberemos buscar en `user` el `nombre` en la clave `name`, quedarnos con el `_id` de ese usuario, y consultar `tweet` buscando documentos cuyo `userid` sea ese valor
#
# - *Nombre*: `retuiteados_sinrep`
# - *Parámetros de entrada*:
#     - `db`: el acceso a una base de datos que se asume incluye una colección `tweet`de tweets
#     - `nombre`: Nombre del usuario. Lo buscaremos en la clave `name` de `user`
# - *Devuelve*: Una lista con las claves  `text` de los documentos en tweet tales que `userid` sea igual al identificador (`_id`) correspondiente al `name`, que habremos obtenido previamente de `user`
# - *Obs*: Si el nombre de usuario no existe debe delvolver la lista vacía; igualmente si un tweet de ese usuario no tiene clave `text` simplemente no se incluira nada en la lista

# %%
def tweets_por_nombre(db, nombre):
    return list(
        db.tweet.find(
            {"userid": {"$in": db.user.distinct("_id", {"name": nombre})}},
            {"_id": False, "text": True},
        )
    )


print("Tweets de Michael Grant ", tweets_por_nombre(db, "Michael Grant"))
print("Tweets de Marky", tweets_por_nombre(db, "Marky"))
# Out:
# Tweets de Michael Grant  [{'text': '@realDonaldTrump Wall will be finished right after ‘great’ health plan is finished. Oh wait.'}, {'text': 'Next to watching @realDonaldTrump face as Biden’s hand comes off the Bible, my next wish is random phone video of @JasonMillerinDC when he internalizes defeat.'}]
# Tweets de Marky [{'text': '🎤 drop #boutthatlife #bidenharris2020 #253 #tacoma #voteblue2020 #inthatorder @kamalaharris @joebiden @ Tacoma, Washington https://t.co/cxdyRNCzvq'}]
