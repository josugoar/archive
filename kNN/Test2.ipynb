# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df1 = pd.read_csv("_KNN/data.csv")
df2 = pd.read_csv("_KNN/label.csv")

fig, ax = plt.subplots()
ax.axis("off")

for i in range(0, len(df)):
    if df2["label"][i] == 0:
        ax.scatter(df["x"][i], df["y"][i], color="#ff0000", alpha=0.5)
    elif df2["label"][i] == 1:
        ax.scatter(df["x"][i], df["y"][i], color="#0000ff", alpha=0.5)
